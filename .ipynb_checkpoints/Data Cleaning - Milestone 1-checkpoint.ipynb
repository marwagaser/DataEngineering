# %%
import pandas as pd
import datetime 
from os import listdir # os is a module for interacting with the OS
from os.path import isfile, join # to verify file object, and concatenate paths
import glob # to find pathnames matching a specific pattern
import re # regular expressions :)
from collections import Counter
import nltk # importing natural language tool
import scipy.stats as st

# %%
#import data set
df = pd.read_csv("./archive.csv")
df.head()
# Out:
#    Year    Category                                           Prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           Motivation Prize Share  Laureate ID  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   Laureate Type                     Full Name  Birth Date         Birth City  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant  1828-05-08             Geneva
# 4    Individual                Frédéric Passy  1822-05-20              Paris
#
#       Birth Country   Sex   Organization Name Organization City  \
# 0       Netherlands  Male   Berlin University            Berlin
# 1            France  Male                 NaN               NaN
# 2  Prussia (Poland)  Male  Marburg University           Marburg
# 3       Switzerland  Male                 NaN               NaN
# 4            France  Male                 NaN               NaN
#
#   Organization Country  Death Date Death City Death Country
# 0              Germany  1911-03-01     Berlin       Germany
# 1                  NaN  1907-09-07   Châtenay        France
# 2              Germany  1917-03-31    Marburg       Germany
# 3                  NaN  1910-10-30     Heiden   Switzerland
# 4                  NaN  1912-06-12      Paris        France

# %% [markdown]
# <h1>Replacing Unwanted Characters in the Data Set</h1>

# %% [markdown]
# <body>To standarize the data in all records, a process of removing the symbols in all columns at once using <i>columns.str.replace</i> will first be tried to limit the characters to be used per column to english alphabets, but <i>columns.str.replace</i> accesses the columns' names not the data in the columns.
#
#  So instead, we use <i>str.replace</i> after specifying the needed column, and that will work on the data values related to that column.
#
# However, we don't just want to remove the symbols, but replace them with the intended letters. For example, if the symbol is '@', we would like to change it to the letter 'a'. And the same will be done with other symbols.</body><br><br>
#
# <body>Through observation, the <i>Full Name</i> attribute, was the one in need of character replacement: <body>

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 969) 
df["Full Name"] = df["Full Name"].str.replace("@","a")
df["Full Name"] = df["Full Name"].str.replace("$","s")
df["Full Name"] = df["Full Name"].str.replace(r"[_!#%^&*()<>?/\|}{~:]+", " ")
df['Full Name']
# Out:
# 0      Jacobus Henricus van 't Hoff
# 1      Sully Prudhomme
# 2      Emil Adolf von Behring
# 3      Jean Henry Dunant
# 4      Frédéric Passy
# 5      Wilhelm Conrad Röntgen
# 6      Hermann Emil Fischer
# 7      Christian Matthias Theodor Mommsen
# 8      Ronald Ross
# 9      Élie Ducommun
# 10     Charles Albert Gobat
# 11     Hendrik Antoon Lorentz
# 12     Pieter Zeeman
# 13     Svante August Arrhenius
# 14     Bjørnstjerne Martinus Bjørnson
# 15     Niels Ryberg Finsen
# 16     William Randal Cremer
# 17     Antoine Henri Becquerel
# 18     Pierre Curie
# 19     Marie Curie, née Sklodowska
# 20     Sir William Ramsay
# 21     Frédéric Mistral
# 22     José Echegaray y Eizaguirre
# 23     Ivan Petrovich Pavlov
# 24     Institut de droit international  Institute of International Law
# 25     Lord Rayleigh  John William Strutt
# 26     Johann Friedrich Wilhelm Adolf von Baeyer
# 27     Henryk Sienkiewicz
# 28     Robert Koch
# 29     Baroness Bertha Sophie Felicita von Suttner, née Countess Kinsky von Chinic und Tettau
# 30     Philipp Eduard Anton von Lenard
# 31     Henri Moissan
# 32     Giosuè Carducci
# 33     Camillo Golgi
# 34     Santiago Ramón y Cajal
# 35     Theodore Roosevelt
# 36     Joseph John Thomson
# 37     Eduard Buchner
# 38     Rudyard Kipling
# 39     Charles Louis Alphonse Laveran
# 40     Ernesto Teodoro Moneta
# 41     Louis Renault
# 42     Albert Abraham Michelson
# 43     Ernest Rutherford
# 44     Rudolf Christoph Eucken
# 45     Ilya Ilyich Mechnikov
# 46     Paul Ehrlich
# 47     Paul Ehrlich
# 48     Klas Pontus Arnoldson
# 49     Fredrik Bajer
# 50     Gabriel Lippmann
# 51     Wilhelm Ostwald
# 52     Selma Ottilia Lovisa Lagerlöf
# 53     Emil Theodor Kocher
# 54     Auguste Marie François Beernaert
# 55     Paul Henri Benjamin Balluet d'Estournelles de Constant, Baron de Constant de Rebecque
# 56     Guglielmo Marconi
# 57     Karl Ferdinand Braun
# 58     Otto Wallach
# 59     Paul Johann Ludwig Heyse
# 60     Albrecht Kossel
# 61     Bureau international permanent de la Paix  Permanent International Peace Bureau
# 62     Johannes Diderik van der Waals
# 63     Marie Curie, née Sklodowska
# 64     Count Maurice  Mooris  Polidore Marie Bernhard Maeterlinck
# 65     Allvar Gullstrand
# 66     Tobias Michael Carel Asser
# 67     Alfred Hermann Fried
# 68     Wilhelm Wien
# 69     Victor Grignard
# 70     Paul Sabatier
# 71     Gerhart Johann Robert Hauptmann
# 72     Alexis Carrel
# 73     Elihu Root
# 74     Nils Gustaf Dalén
# 75     Alfred Werner
# 76     Rabindranath Tagore
# 77     Charles Robert Richet
# 78     Henri La Fontaine
# 79     Heike Kamerlingh Onnes
# 80     Theodore William Richards
# 81     Robert Bárány
# 82     Max von Laue
# 83     Richard Martin Willstätter
# 84     Romain Rolland
# 85     Sir William Henry Bragg
# 86     William Lawrence Bragg
# 87     Carl Gustaf Verner von Heidenstam
# 88     Karl Adolph Gjellerup
# 89     Henrik Pontoppidan
# 90     Comité international de la Croix Rouge  International Committee of the Red Cross
# 91     Charles Glover Barkla
# 92     Fritz Haber
# 93     Max Karl Ernst Ludwig Planck
# 94     Carl Friedrich Georg Spitteler
# 95     Jules Bordet
# 96     Thomas Woodrow Wilson
# 97     Johannes Stark
# 98     Walther Hermann Nernst
# 99     Knut Pedersen Hamsun
# 100    Schack August Steenberg Krogh
# 101    Léon Victor Auguste Bourgeois
# 102    Charles Edouard Guillaume
# 103    Frederick Soddy
# 104    Anatole France
# 105    Karl Hjalmar Branting
# 106    Christian Lous Lange
# 107    Albert Einstein
# 108    Francis William Aston
# 109    Jacinto Benavente
# 110    Archibald Vivian Hill
# 111    Otto Fritz Meyerhof
# 112    Fridtjof Nansen
# 113    Niels Henrik David Bohr
# 114    Fritz Pregl
# 115    William Butler Yeats
# 116    Frederick Grant Banting
# 117    John James Rickard Macleod
# 118    Robert Andrews Millikan
# 119    Wladyslaw Stanislaw Reymont
# 120    Willem Einthoven
# 121    Karl Manne Georg Siegbahn
# 122    Richard Adolf Zsigmondy
# 123    George Bernard Shaw
# 124    Sir Austen Chamberlain
# 125    Charles Gates Dawes
# 126    James Franck
# 127    Gustav Ludwig Hertz
# 128    The  Theodor  Svedberg
# 129    Grazia Deledda
# 130    Johannes Andreas Grib Fibiger
# 131    Aristide Briand
# 132    Gustav Stresemann
# 133    Jean Baptiste Perrin
# 134    Heinrich Otto Wieland
# 135    Henri Bergson
# 136    Julius Wagner-Jauregg
# 137    Ferdinand Buisson
# 138    Ludwig Quidde
# 139    Arthur Holly Compton
# 140    Charles Thomson Rees Wilson
# 141    Adolf Otto Reinhold Windaus
# 142    Sigrid Undset
# 143    Charles Jules Henri Nicolle
# 144    Owen Willans Richardson
# 145    Arthur Harden
# 146    Hans Karl August Simon von Euler-Chelpin
# 147    Thomas Mann
# 148    Christiaan Eijkman
# 149    Sir Frederick Gowland Hopkins
# 150    Frank Billings Kellogg
# 151    Prince Louis-Victor Pierre Raymond de Broglie
# 152    Hans Fischer
# 153    Sinclair Lewis
# 154    Karl Landsteiner
# 155    Lars Olof Jonathan  Nathan  Söderblom
# 156    Sir Chandrasekhara Venkata Raman
# 157    Carl Bosch
# 158    Carl Bosch
# 159    Friedrich Bergius
# 160    Friedrich Bergius
# 161    Erik Axel Karlfeldt
# 162    Otto Heinrich Warburg
# 163    Jane Addams
# 164    Nicholas Murray Butler
# 165    Irving Langmuir
# 166    John Galsworthy
# 167    Sir Charles Scott Sherrington
# 168    Edgar Douglas Adrian
# 169    Werner Karl Heisenberg
# 170    Ivan Alekseyevich Bunin
# 171    Thomas Hunt Morgan
# 172    Sir Norman Angell  Ralph Lane
# 173    Erwin Schrödinger
# 174    Paul Adrien Maurice Dirac
# 175    Harold Clayton Urey
# 176    Luigi Pirandello
# 177    George Hoyt Whipple
# 178    George Richards Minot
# 179    William Parry Murphy
# 180    William Parry Murphy
# 181    Arthur Henderson
# 182    Frédéric Joliot
# 183    Irène Joliot-Curie
# 184    Hans Spemann
# 185    Carl von Ossietzky
# 186    James Chadwick
# 187    Petrus  Peter  Josephus Wilhelmus Debye
# 188    Petrus  Peter  Josephus Wilhelmus Debye
# 189    Eugene Gladstone O'Neill
# 190    Sir Henry Hallett Dale
# 191    Otto Loewi
# 192    Carlos Saavedra Lamas
# 193    Victor Franz Hess
# 194    Carl David Anderson
# 195    Walter Norman Haworth
# 196    Paul Karrer
# 197    Roger Martin du Gard
# 198    Albert von Szent-Györgyi Nagyrápolt
# 199    Cecil of Chelwood, Viscount  Lord Edgar Algernon Robert Gascoyne Cecil
# 200    Clinton Joseph Davisson
# 201    George Paget Thomson
# 202    Richard Kuhn
# 203    Richard Kuhn
# 204    Pearl Buck
# 205    Corneille Jean François Heymans
# 206    Office international Nansen pour les Réfugiés  Nansen International Office for Refugees
# 207    Enrico Fermi
# 208    Adolf Friedrich Johann Butenandt
# 209    Adolf Friedrich Johann Butenandt
# 210    Leopold Ruzicka
# 211    Frans Eemil Sillanpää
# 212    Gerhard Domagk
# 213    Ernest Orlando Lawrence
# 214    George de Hevesy
# 215    Henrik Carl Peter Dam
# 216    Edward Adelbert Doisy
# 217    Otto Stern
# 218    Otto Hahn
# 219    Johannes Vilhelm Jensen
# 220    Joseph Erlanger
# 221    Herbert Spencer Gasser
# 222    Comité international de la Croix Rouge  International Committee of the Red Cross
# 223    Isidor Isaac Rabi
# 224    Artturi Ilmari Virtanen
# 225    Gabriela Mistral
# 226    Sir Alexander Fleming
# 227    Ernst Boris Chain
# 228    Sir Howard Walter Florey
# 229    Cordell Hull
# 230    Wolfgang Pauli
# 231    James Batcheller Sumner
# 232    John Howard Northrop
# 233    Wendell Meredith Stanley
# 234    Hermann Hesse
# 235    Hermann Joseph Muller
# 236    Emily Greene Balch
# 237    John Raleigh Mott
# 238    Percy Williams Bridgman
# 239    Sir Robert Robinson
# 240    André Paul Guillaume Gide
# 241    Carl Ferdinand Cori
# 242    Gerty Theresa Cori, née Radnitz
# 243    Bernardo Alberto Houssay
# 244    Friends Service Council  The Quakers
# 245    American Friends Service Committee  The Quakers
# 246    Sir Edward Victor Appleton
# 247    Arne Wilhelm Kaurin Tiselius
# 248    Thomas Stearns Eliot
# 249    Paul Hermann Müller
# 250    Patrick Maynard Stuart Blackett
# 251    William Francis Giauque
# 252    William Faulkner
# 253    Walter Rudolf Hess
# 254    Antonio Caetano de Abreu Freire Egas Moniz
# 255    Antonio Caetano de Abreu Freire Egas Moniz
# 256    Lord  John  Boyd Orr of Brechin
# 257    Hideki Yukawa
# 258    Hideki Yukawa
# 259    Otto Paul Hermann Diels
# 260    Kurt Alder
# 261    Earl  Bertrand Arthur William  Russell
# 262    Edward Calvin Kendall
# 263    Tadeus Reichstein
# 264    Philip Showalter Hench
# 265    Ralph Bunche
# 266    Cecil Frank Powell
# 267    Edwin Mattison McMillan
# 268    Glenn Theodore Seaborg
# 269    Pär Fabian Lagerkvist
# 270    Max Theiler
# 271    Léon Jouhaux
# 272    Sir John Douglas Cockcroft
# 273    Ernest Thomas Sinton Walton
# 274    Archer John Porter Martin
# 275    Richard Laurence Millington Synge
# 276    François Mauriac
# 277    Selman Abraham Waksman
# 278    Albert Schweitzer
# 279    Felix Bloch
# 280    Edward Mills Purcell
# 281    Hermann Staudinger
# 282    Hermann Staudinger
# 283    Sir Winston Leonard Spencer Churchill
# 284    Hans Adolf Krebs
# 285    Fritz Albert Lipmann
# 286    Fritz Albert Lipmann
# 287    George Catlett Marshall
# 288    Frits Zernike
# 289    Linus Carl Pauling
# 290    Ernest Miller Hemingway
# 291    John Franklin Enders
# 292    John Franklin Enders
# 293    Thomas Huckle Weller
# 294    Frederick Chapman Robbins
# 295    Office of the United Nations High Commissioner for Refugees  UNHCR
# 296    Max Born
# 297    Walther Bothe
# 298    Walther Bothe
# 299    Vincent du Vigneaud
# 300    Halldór Kiljan Laxness
# 301    Axel Hugo Theodor Theorell
# 302    Willis Eugene Lamb
# 303    Polykarp Kusch
# 304    Sir Cyril Norman Hinshelwood
# 305    Nikolay Nikolaevich Semenov
# 306    Juan Ramón Jiménez
# 307    André Frédéric Cournand
# 308    Werner Forssmann
# 309    Werner Forssmann
# 310    Dickinson W. Richards
# 311    William Bradford Shockley
# 312    John Bardeen
# 313    Walter Houser Brattain
# 314    Lord  Alexander R.  Todd
# 315    Albert Camus
# 316    Daniel Bovet
# 317    Lester Bowles Pearson
# 318    Chen Ning Yang
# 319    Tsung-Dao  T.D.  Lee
# 320    Frederick Sanger
# 321    Boris Leonidovich Pasternak
# 322    George Wells Beadle
# 323    Edward Lawrie Tatum
# 324    Joshua Lederberg
# 325    Georges Pire
# 326    Pavel Alekseyevich Cherenkov
# 327    Igor Yevgenyevich Tamm
# 328    Igor Yevgenyevich Tamm
# 329    Il´ja Mikhailovich Frank
# 330    Il´ja Mikhailovich Frank
# 331    Jaroslav Heyrovsky
# 332    Salvatore Quasimodo
# 333    Severo Ochoa
# 334    Arthur Kornberg
# 335    Philip J. Noel-Baker
# 336    Emilio Gino Segrè
# 337    Owen Chamberlain
# 338    Willard Frank Libby
# 339    Saint-John Perse
# 340    Sir Frank Macfarlane Burnet
# 341    Peter Brian Medawar
# 342    Albert John Lutuli
# 343    Donald Arthur Glaser
# 344    Melvin Calvin
# 345    Ivo Andric
# 346    Georg von Békésy
# 347    Dag Hjalmar Agne Carl Hammarskjöld
# 348    Robert Hofstadter
# 349    Rudolf Ludwig Mössbauer
# 350    Rudolf Ludwig Mössbauer
# 351    Max Ferdinand Perutz
# 352    John Cowdery Kendrew
# 353    John Steinbeck
# 354    Francis Harry Compton Crick
# 355    James Dewey Watson
# 356    Maurice Hugh Frederick Wilkins
# 357    Linus Carl Pauling
# 358    Lev Davidovich Landau
# 359    Karl Ziegler
# 360    Giulio Natta
# 361    Giorgos Seferis
# 362    Sir John Carew Eccles
# 363    Alan Lloyd Hodgkin
# 364    Andrew Fielding Huxley
# 365    Comité international de la Croix Rouge  International Committee of the Red Cross
# 366    Ligue des Sociétés de la Croix-Rouge  League of Red Cross Societies
# 367    Eugene Paul Wigner
# 368    Maria Goeppert Mayer
# 369    J. Hans D. Jensen
# 370    Dorothy Crowfoot Hodgkin
# 371    Jean-Paul Sartre
# 372    Konrad Bloch
# 373    Feodor Lynen
# 374    Martin Luther King Jr.
# 375    Charles Hard Townes
# 376    Nicolay Gennadiyevich Basov
# 377    Aleksandr Mikhailovich Prokhorov
# 378    Robert Burns Woodward
# 379    Mikhail Aleksandrovich Sholokhov
# 380    François Jacob
# 381    André Lwoff
# 382    Jacques Monod
# 383    United Nations Children's Fund  UNICEF
# 384    Sin-Itiro Tomonaga
# 385    Julian Schwinger
# 386    Richard P. Feynman
# 387    Robert S. Mulliken
# 388    Shmuel Yosef Agnon
# 389    Nelly Sachs
# 390    Peyton Rous
# 391    Charles Brenton Huggins
# 392    Alfred Kastler
# 393    Manfred Eigen
# 394    Ronald George Wreyford Norrish
# 395    George Porter
# 396    Miguel Angel Asturias
# 397    Ragnar Granit
# 398    Haldan Keffer Hartline
# 399    George Wald
# 400    Hans Albrecht Bethe
# 401    Lars Onsager
# 402    Yasunari Kawabata
# 403    Robert W. Holley
# 404    Har Gobind Khorana
# 405    Marshall W. Nirenberg
# 406    René Cassin
# 407    Luis Walter Alvarez
# 408    Derek H. R. Barton
# 409    Odd Hassel
# 410    Ragnar Frisch
# 411    Jan Tinbergen
# 412    Samuel Beckett
# 413    Max Delbrück
# 414    Alfred D. Hershey
# 415    Salvador E. Luria
# 416    International Labour Organization  I.L.O.
# 417    Murray Gell-Mann
# 418    Luis F. Leloir
# 419    Paul A. Samuelson
# 420    Aleksandr Isayevich Solzhenitsyn
# 421    Sir Bernard Katz
# 422    Ulf von Euler
# 423    Julius Axelrod
# 424    Norman E. Borlaug
# 425    Hannes Olof Gösta Alfvén
# 426    Louis Eugène Félix Néel
# 427    Gerhard Herzberg
# 428    Simon Kuznets
# 429    Pablo Neruda
# 430    Earl W. Sutherland, Jr.
# 431    Willy Brandt
# 432    Dennis Gabor
# 433    Christian B. Anfinsen
# 434    Stanford Moore
# 435    William H. Stein
# 436    John R. Hicks
# 437    Kenneth J. Arrow
# 438    Heinrich Böll
# 439    Gerald M. Edelman
# 440    Rodney R. Porter
# 441    John Bardeen
# 442    Leon Neil Cooper
# 443    John Robert Schrieffer
# 444    Ernst Otto Fischer
# 445    Geoffrey Wilkinson
# 446    Wassily Leontief
# 447    Patrick White
# 448    Karl von Frisch
# 449    Konrad Lorenz
# 450    Nikolaas Tinbergen
# 451    Henry A. Kissinger
# 452    Le Duc Tho
# 453    Leo Esaki
# 454    Ivar Giaever
# 455    Brian David Josephson
# 456    Paul J. Flory
# 457    Gunnar Myrdal
# 458    Friedrich August von Hayek
# 459    Eyvind Johnson
# 460    Harry Martinson
# 461    Albert Claude
# 462    Christian de Duve
# 463    Christian de Duve
# 464    George E. Palade
# 465    Seán MacBride
# 466    Eisaku Sato
# 467    Sir Martin Ryle
# 468    Antony Hewish
# 469    John Warcup Cornforth
# 470    Vladimir Prelog
# 471    Leonid Vitaliyevich Kantorovich
# 472    Tjalling C. Koopmans
# 473    Eugenio Montale
# 474    David Baltimore
# 475    Renato Dulbecco
# 476    Howard Martin Temin
# 477    Andrei Dmitrievich Sakharov
# 478    Aage Niels Bohr
# 479    Ben Roy Mottelson
# 480    Leo James Rainwater
# 481    William N. Lipscomb
# 482    Milton Friedman
# 483    Saul Bellow
# 484    Baruch S. Blumberg
# 485    D. Carleton Gajdusek
# 486    Betty Williams
# 487    Mairead Corrigan
# 488    Burton Richter
# 489    Samuel Chao Chung Ting
# 490    Ilya Prigogine
# 491    Ilya Prigogine
# 492    Bertil Ohlin
# 493    James E. Meade
# 494    Vicente Aleixandre
# 495    Roger Guillemin
# 496    Andrew V. Schally
# 497    Rosalyn Yalow
# 498    Amnesty International
# 499    Philip Warren Anderson
# ...
# 803    Thomas C. Schelling
# 804    Harold Pinter
# 805    Barry J. Marshall
# 806    Barry J. Marshall
# 807    J. Robin Warren
# 808    International Atomic Energy Agency  IAEA
# 809    Mohamed ElBaradei
# 810    Roy J. Glauber
# 811    John L. Hall
# 812    John L. Hall
# 813    Theodor W. Hänsch
# 814    Theodor W. Hänsch
# 815    Roger D. Kornberg
# 816    Edmund S. Phelps
# 817    Orhan Pamuk
# 818    Andrew Z. Fire
# 819    Craig C. Mello
# 820    Muhammad Yunus
# 821    Grameen Bank
# 822    John C. Mather
# 823    George F. Smoot
# 824    Gerhard Ertl
# 825    Leonid Hurwicz
# 826    Eric S. Maskin
# 827    Roger B. Myerson
# 828    Doris Lessing
# 829    Mario R. Capecchi
# 830    Mario R. Capecchi
# 831    Sir Martin J. Evans
# 832    Oliver Smithies
# 833    Intergovernmental Panel on Climate Change  IPCC
# 834    Albert Arnold  Al  Gore Jr.
# 835    Albert Fert
# 836    Albert Fert
# 837    Peter Grünberg
# 838    Osamu Shimomura
# 839    Osamu Shimomura
# 840    Martin Chalfie
# 841    Roger Y. Tsien
# 842    Roger Y. Tsien
# 843    Paul Krugman
# 844    Jean-Marie Gustave Le Clézio
# 845    Harald zur Hausen
# 846    Françoise Barré-Sinoussi
# 847    Luc Montagnier
# 848    Martti Ahtisaari
# 849    Yoichiro Nambu
# 850    Makoto Kobayashi
# 851    Toshihide Maskawa
# 852    Toshihide Maskawa
# 853    Venkatraman Ramakrishnan
# 854    Thomas A. Steitz
# 855    Thomas A. Steitz
# 856    Ada E. Yonath
# 857    Elinor Ostrom
# 858    Elinor Ostrom
# 859    Oliver E. Williamson
# 860    Herta Müller
# 861    Elizabeth H. Blackburn
# 862    Carol W. Greider
# 863    Jack W. Szostak
# 864    Jack W. Szostak
# 865    Jack W. Szostak
# 866    Barack H. Obama
# 867    Charles Kuen Kao
# 868    Charles Kuen Kao
# 869    Willard S. Boyle
# 870    George E. Smith
# 871    Richard F. Heck
# 872    Ei-ichi Negishi
# 873    Akira Suzuki
# 874    Peter A. Diamond
# 875    Dale T. Mortensen
# 876    Dale T. Mortensen
# 877    Christopher A. Pissarides
# 878    Mario Vargas Llosa
# 879    Robert G. Edwards
# 880    Liu Xiaobo
# 881    Andre Geim
# 882    Konstantin Novoselov
# 883    Dan Shechtman
# 884    Thomas J. Sargent
# 885    Christopher A. Sims
# 886    Tomas Tranströmer
# 887    Bruce A. Beutler
# 888    Bruce A. Beutler
# 889    Jules A. Hoffmann
# 890    Ralph M. Steinman
# 891    Ellen Johnson Sirleaf
# 892    Leymah Gbowee
# 893    Tawakkol Karman
# 894    Saul Perlmutter
# 895    Saul Perlmutter
# 896    Brian P. Schmidt
# 897    Adam G. Riess
# 898    Adam G. Riess
# 899    Robert J. Lefkowitz
# 900    Robert J. Lefkowitz
# 901    Brian K. Kobilka
# 902    Alvin E. Roth
# 903    Alvin E. Roth
# 904    Lloyd S. Shapley
# 905    Mo Yan
# 906    Sir John B. Gurdon
# 907    Shinya Yamanaka
# 908    Shinya Yamanaka
# 909    European Union  EU
# 910    Serge Haroche
# 911    Serge Haroche
# 912    David J. Wineland
# 913    David J. Wineland
# 914    Martin Karplus
# 915    Martin Karplus
# 916    Michael Levitt
# 917    Arieh Warshel
# 918    Eugene F. Fama
# 919    Lars Peter Hansen
# 920    Robert J. Shiller
# 921    Alice Munro
# 922    James E. Rothman
# 923    Randy W. Schekman
# 924    Randy W. Schekman
# 925    Thomas C. Südhof
# 926    Thomas C. Südhof
# 927    Organisation for the Prohibition of Chemical Weapons  OPCW
# 928    François Englert
# 929    Peter W. Higgs
# 930    Eric Betzig
# 931    Stefan W. Hell
# 932    Stefan W. Hell
# 933    William E. Moerner
# 934    Jean Tirole
# 935    Patrick Modiano
# 936    John O'Keefe
# 937    May-Britt Moser
# 938    Edvard I. Moser
# 939    Kailash Satyarthi
# 940    Malala Yousafzai
# 941    Isamu Akasaki
# 942    Isamu Akasaki
# 943    Hiroshi Amano
# 944    Shuji Nakamura
# 945    Tomas Lindahl
# 946    Tomas Lindahl
# 947    Paul Modrich
# 948    Paul Modrich
# 949    Aziz Sancar
# 950    Angus Deaton
# 951    Svetlana Alexievich
# 952    William C. Campbell
# 953    Satoshi Ōmura
# 954    Youyou Tu
# 955    National Dialogue Quartet
# 956    Takaaki Kajita
# 957    Arthur B. McDonald
# 958    Jean-Pierre Sauvage
# 959    Sir J. Fraser Stoddart
# 960    Bernard L. Feringa
# 961    Oliver Hart
# 962    Bengt Holmström
# 963    Bob Dylan
# 964    Yoshinori Ohsumi
# 965    Juan Manuel Santos
# 966    David J. Thouless
# 967    F. Duncan M. Haldane
# 968    J. Michael Kosterlitz
# Name: Full Name, dtype: object

# %% [markdown]
# <body> We also notice in the <i>Full Name</i> attribute, that some records, exactly four as we can see below, contain the birth city as well.<br>
# So we remove the part containing the birth city, since we already have a <i>Birth City</i> attribute handling this info, as there is no need for repetition.<br>
# The word "née" means born in french.</body>

# %%
d1 = df[df['Full Name'].str.contains('née') == True]
print(d1["Full Name"].count())
d1
# Out:
# 4
#      Year   Category                                           Prize  \
# 19   1903  Physics    The Nobel Prize in Physics 1903
# 29   1905  Peace      The Nobel Peace Prize 1905
# 63   1911  Chemistry  The Nobel Prize in Chemistry 1911
# 242  1947  Medicine   The Nobel Prize in Physiology or Medicine 1947
#
#                                                                                                                                                                                                                  Motivation  \
# 19   "in recognition of the extraordinary services they have rendered by their joint researches on the radiation phenomena discovered by Professor Henri Becquerel"
# 29   NaN
# 63   "in recognition of her services to the advancement of chemistry by the discovery of the elements radium and polonium, by the isolation of radium and the study of the nature and compounds of this remarkable element"
# 242  "for their discovery of the course of the catalytic conversion of glycogen"
#
#     Prize Share  Laureate ID Laureate Type  \
# 19   1/4         6            Individual
# 29   1/1         468          Individual
# 63   1/1         6            Individual
# 242  1/4         344          Individual
#
#                                                                                   Full Name  \
# 19   Marie Curie, née Sklodowska
# 29   Baroness Bertha Sophie Felicita von Suttner, née Countess Kinsky von Chinic und Tettau
# 63   Marie Curie, née Sklodowska
# 242  Gerty Theresa Cori, née Radnitz
#
#      Birth Date Birth City                     Birth Country     Sex  \
# 19   1867-11-07  Warsaw     Russian Empire (Poland)           Female
# 29   1843-06-09  Prague     Austrian Empire (Czech Republic)  Female
# 63   1867-11-07  Warsaw     Russian Empire (Poland)           Female
# 242  1896-08-15  Prague     Austria-Hungary (Czech Republic)  Female
#
#          Organization Name Organization City      Organization Country  \
# 19   NaN                    NaN               NaN
# 29   NaN                    NaN               NaN
# 63   Sorbonne University    Paris             France
# 242  Washington University  St. Louis, MO     United States of America
#
#      Death Date     Death City             Death Country
# 19   1934-07-04  Sallanches     France
# 29   1914-06-21  Vienna         Austria
# 63   1934-07-04  Sallanches     France
# 242  1957-10-26  St. Louis, MO  United States of America

# %% [markdown]
# Now we remove this extra part from the four shown previous records:

# %%
df["Full Name"] = df["Full Name"].str.replace(", née Sklodowska","")
df["Full Name"] = df["Full Name"].str.replace(", née Countess Kinsky von Chinic und Tettau","")
df["Full Name"] = df["Full Name"].str.replace(", née Radnitz","")
d2 = df[df['Full Name'].str.contains('née') == True]
print(d2["Full Name"].count())
d2
# Out:
# 0
# Empty DataFrame
# Columns: [Year, Category, Prize, Motivation, Prize Share, Laureate ID, Laureate Type, Full Name, Birth Date, Birth City, Birth Country, Sex, Organization Name, Organization City, Organization Country, Death Date, Death City, Death Country]
# Index: []

# %% [markdown]
# In addition to standarizing the characters to English only, the removal of the double quotation marks from the <i>Motivation</i> is essential to later perform analysis

# %%
df["Motivation"] = df["Motivation"].str.replace('"', '')

# %%
df
# Out:
#      Year    Category                                           Prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 964  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965  2016       Peace                      The Nobel Peace Prize 2016
# 966  2016     Physics                 The Nobel Prize in Physics 2016
# 967  2016     Physics                 The Nobel Prize in Physics 2016
# 968  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             Motivation Prize Share  \
# 0    in recognition of the extraordinary services h...         1/1
# 1    in special recognition of his poetic compositi...         1/1
# 2    for his work on serum therapy, especially its ...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 964    for his discoveries of mechanisms for autophagy         1/1
# 965  for his resolute efforts to bring the country'...         1/1
# 966  for theoretical discoveries of topological pha...         1/2
# 967  for theoretical discoveries of topological pha...         1/4
# 968  for theoretical discoveries of topological pha...         1/4
#
#      Laureate ID Laureate Type                    Full Name  Birth Date  \
# 0            160    Individual  Jacobus Henricus van t Hoff  1852-08-30
# 1            569    Individual              Sully Prudhomme  1839-03-16
# 2            293    Individual       Emil Adolf von Behring  1854-03-15
# 3            462    Individual            Jean Henry Dunant  1828-05-08
# 4            463    Individual               Frederic Passy  1822-05-20
# ..           ...           ...                          ...         ...
# 964          927    Individual             Yoshinori Ohsumi  1945-02-09
# 965          934    Individual           Juan Manuel Santos  1951-08-10
# 966          928    Individual             David J Thouless  1934-09-21
# 967          929    Individual           F Duncan M Haldane  1951-09-14
# 968          930    Individual         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 964            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 965             Bogotá          Colombia  Male                            NaN
# 966           Bearsden    United Kingdom  Male       University of Washington
# 967             London    United Kingdom  Male           Princeton University
# 968           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Ch tenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 964             Tokyo                     Japan         NaN        NaN
# 965               NaN                       NaN         NaN        NaN
# 966       Seattle, WA  United States of America         NaN        NaN
# 967     Princeton, NJ  United States of America         NaN        NaN
# 968    Providence, RI  United States of America         NaN        NaN
#
#     Death Country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 964           NaN
# 965           NaN
# 966           NaN
# 967           NaN
# 968           NaN
#
# [969 rows x 18 columns]

# %% [markdown]
# <h1>Checking missing Values</h1>
# <body>In the below steps, an observation of the null values in the data frame is to be made</body>

# %%
#display sum of missing values
df_nulls = df.isnull().sum()
df_nulls
# Out:
# Year                      0
# Category                  0
# Prize                     0
# Motivation               88
# Prize Share               0
# Laureate ID               0
# Laureate Type             0
# Full Name                 0
# Birth Date               29
# Birth City               28
# Birth Country            26
# Sex                      26
# Organization Name       247
# Organization City       253
# Organization Country    253
# Death Date              352
# Death City              370
# Death Country           364
# dtype: int64

# %% [markdown]
# It seems like the<i> Birth City</i> is missing 28 values. Let's see which of the winners have those missing <i> Birth City</i> values

# %%
#copy the full name, birth city, birth date, laureate type, organization city, organization name, and sex
newdf = df[['Full Name','Birth City','Birth Date', 'Laureate Type','Organization Country','Organization City','Organization Name','Sex']].copy()
newdf
#display the rows in which the Birth City is null
d1 = newdf[(newdf['Birth City'].isnull())]
d1
# Out:
#                                              Full Name Birth City  Birth Date  \
# 24   Institut de droit international Institute of I...        NaN         NaN
# 61   Bureau international permanent de la Paix Perm...        NaN         NaN
# 90   Comite international de la Croix Rouge Interna...        NaN         NaN
# 206  Office international Nansen pour les Refugies ...        NaN         NaN
# 222  Comite international de la Croix Rouge Interna...        NaN         NaN
# 244               Friends Service Council The Quakers         NaN         NaN
# 245    American Friends Service Committee The Quakers         NaN         NaN
# 295  Office of the United Nations High Commissioner...        NaN         NaN
# 365  Comite international de la Croix Rouge Interna...        NaN         NaN
# 366  Ligue des Societes de la Croix Rouge League of...        NaN         NaN
# 383             United Nations Children s Fund UNICEF         NaN         NaN
# 416           International Labour Organization I L O         NaN         NaN
# 498                              Amnesty International        NaN         NaN
# 543  Office of the United Nations High Commissioner...        NaN         NaN
# 578  International Physicians for the Prevention of...        NaN         NaN
# 610                 United Nations Peacekeeping Forces        NaN         NaN
# 682   Pugwash Conferences on Science and World Affairs        NaN         NaN
# 705      International Campaign to Ban Landmines ICBL         NaN         NaN
# 728                           Medecins Sans Fronti res        NaN         NaN
# 750                  Sir Vidiadhar Surajprasad Naipaul        NaN  1932-08-17
# 754                                United Nations U N         NaN         NaN
# 808           International Atomic Energy Agency IAEA         NaN         NaN
# 821                                       Grameen Bank        NaN         NaN
# 833    Intergovernmental Panel on Climate Change IPCC         NaN         NaN
# 880                                         Liu Xiaobo        NaN  1955-12-28
# 909                                 European Union EU         NaN         NaN
# 927  Organisation for the Prohibition of Chemical W...        NaN         NaN
# 955                          National Dialogue Quartet        NaN         NaN
#
#     Laureate Type Organization Country Organization City Organization Name  \
# 24   Organization                  NaN               NaN               NaN
# 61   Organization                  NaN               NaN               NaN
# 90   Organization                  NaN               NaN               NaN
# 206  Organization                  NaN               NaN               NaN
# 222  Organization                  NaN               NaN               NaN
# 244  Organization                  NaN               NaN               NaN
# 245  Organization                  NaN               NaN               NaN
# 295  Organization                  NaN               NaN               NaN
# 365  Organization                  NaN               NaN               NaN
# 366  Organization                  NaN               NaN               NaN
# 383  Organization                  NaN               NaN               NaN
# 416  Organization                  NaN               NaN               NaN
# 498  Organization                  NaN               NaN               NaN
# 543  Organization                  NaN               NaN               NaN
# 578  Organization                  NaN               NaN               NaN
# 610  Organization                  NaN               NaN               NaN
# 682  Organization                  NaN               NaN               NaN
# 705  Organization                  NaN               NaN               NaN
# 728  Organization                  NaN               NaN               NaN
# 750    Individual                  NaN               NaN               NaN
# 754  Organization                  NaN               NaN               NaN
# 808  Organization                  NaN               NaN               NaN
# 821  Organization                  NaN               NaN               NaN
# 833  Organization                  NaN               NaN               NaN
# 880    Individual                  NaN               NaN               NaN
# 909  Organization                  NaN               NaN               NaN
# 927  Organization                  NaN               NaN               NaN
# 955  Organization                  NaN               NaN               NaN
#
#       Sex
# 24    NaN
# 61    NaN
# 90    NaN
# 206   NaN
# 222   NaN
# 244   NaN
# 245   NaN
# 295   NaN
# 365   NaN
# 366   NaN
# 383   NaN
# 416   NaN
# 498   NaN
# 543   NaN
# 578   NaN
# 610   NaN
# 682   NaN
# 705   NaN
# 728   NaN
# 750  Male
# 754   NaN
# 808   NaN
# 821   NaN
# 833   NaN
# 880  Male
# 909   NaN
# 927   NaN
# 955   NaN

# %% [markdown]
# <h1>Observation</h1>
# <span>As you might have noticed most of the <i> Birth City</i> missing values are coming from <i>Laureate Type</i>: <i>Organization</i>. Not only is the <i> Birth City</i> missing, but also the <i> Birth Date</i>, <i>Sex</i>, <i> Organization Name</i>, <i> Organization City</i>, and <i> Organization Country</i>. This makes sense, as winning as an organization means that you are a group of people which might come from different univeristies (organization), birth cities, organization countries, cities, and are of differenet sexes. Besides, each of them might have a different birth date</span>
# <br><br>
# <span>Moreover, for the <i>Laureate Type</i>: <i>Organization</i>, the <i>Full Name</i> contains the name of the organization, not the name of the person. This is an indication that they are a group not an individual person who won the Nobel prize</span>

# %%
organizationCount = newdf[(newdf['Laureate Type']=="Organization")].count() 
# from the above line we can observe the number of existing birth city when the laureate type is organization

#check the number of rows with missing Birth City and laureate type of individual
countBirthIndividual = newdf[(newdf['Birth City'].isnull()) &(newdf['Laureate Type']=="Individual")].count()
display(organizationCount,countBirthIndividual)
# Out:
# Full Name               30
# Birth City               4
# Birth Date               4
# Laureate Type           30
# Organization Country     0
# Organization City        0
# Organization Name        0
# Sex                      4
# dtype: int64
# Full Name               2
# Birth City              0
# Birth Date              2
# Laureate Type           2
# Organization Country    0
# Organization City       0
# Organization Name       0
# Sex                     2
# dtype: int64

# %% [markdown]
# <h1>Checking number of organization laureate type</h1>
# <span>What we want to observe is the number of organization laureate type, and those with missing birth city, organization name, organization country, organization city, birth date, and sex</span>

# %%
missingOrganization = newdf[(newdf['Laureate Type']=="Organization")&(newdf['Organization Name'].isnull())&(newdf['Organization City'].isnull())&(newdf['Organization Country'].isnull())&(newdf['Birth City'].isnull())&(newdf['Sex'].isnull())&(newdf['Birth Date'].isnull())].count()
missingOrganization
# Out:
# Full Name               26
# Birth City               0
# Birth Date               0
# Laureate Type           26
# Organization Country     0
# Organization City        0
# Organization Name        0
# Sex                      0
# dtype: int64

# %% [markdown]
# <h1> Analyzing the above result </h1>
# The number of rows of laureate type organization which contain missing organization info, sex, birth date, and birth city are 26/30 rows. Likewise, only 4 rows contained birth city even without checking on the organization info (Organization name, city, and country). Now let's check the rows which contain the birth city and are of laurete type orgainzation.

# %%
#checking the 4 rows which contain birth date, birth city, sex, and are of type organization
laureate_org_expection = newdf[(newdf['Laureate Type'] == 'Organization') & (newdf['Sex'].notnull()) & (newdf['Birth Date'].notnull())& (newdf['Birth City'].notnull())]
laureate_org_expection
# Out:
#                               Full Name        Birth City  Birth Date  \
# 452                          Le Duc Tho   Nam Ha province  1911-10-14
# 520                       Mother Teresa    Uskup (Skopje)  1910-08-26
# 620  The 14th Dalai Lama Tenzin Gyatso            Taktser  1935-07-06
# 640                    Aung San Suu Kyi  Rangoon (Yangon)  1945-06-19
#
#     Laureate Type Organization Country Organization City Organization Name  \
# 452  Organization                  NaN               NaN               NaN
# 520  Organization                  NaN               NaN               NaN
# 620  Organization                  NaN               NaN               NaN
# 640  Organization                  NaN               NaN               NaN
#
#         Sex
# 452    Male
# 520  Female
# 620    Male
# 640  Female

# %% [markdown]
# <h1> Why do sexes, birth dates, and birth cities exist above? </h1>
# <span>It seems like not only the birth city, birth date, and sex exist, but also, the full names are names of actual people and not a group. This might indicate that those people were part of an organization, or this data is mistakenly categorized as of laureate type <span style ="font-style:italic">Organization<span> </span>

# %% [markdown]
# <h1>Checking if we can drop rows of <span style ="font-style:italic">Laureate Type:</span> <span style ="font-style:italic">Organization</span> </h1>
# <body>Let's check how many rows of <i>Laureate Type</i> <i>Organization</i> exist. If they are less or equal to 3% perecent of the data, we will choose to drop any column of type organization and focus our study on individuals.<br><br>
# The reasons behind dropping the values are the missing data in records of <i>Laureate Type </i>: <i>Organization</i>. Besides, <i>Full Name</i> attribute for winners with a <i>Laureate Type</i> of <i>Organization</i> is an organization name (except for 4 records where the <i>Full Name</i> is the name of a person).<br><br> Therefore, due to all these inconsistencies and missing values. The observation was to be focused on <i>Laureate Type:</i>  <i>Individual</i> </body>

# %%
# How many total missing values do we have?
# shape returns the dimentionality of a dataframe (rows and columns)
# how many rows exist in the data set
dfNumofRows = df.shape[0]
# how many rows exist with type organization
laureateOrganization_df = newdf[(newdf['Laureate Type']=="Organization")]
orgNumofRows= laureateOrganization_df.shape[0]
#calculate the perecentage of organization data with respect to the whole data set
perc_drop= (orgNumofRows/dfNumofRows)*100
perc_drop
# Out:
# 3.0959752321981426

# %% [markdown]
# Since the perecentage of the rows to be dropped, rows which carry laureate type <span style ="font-style:italic">Organization</span> is approximately 3, we will choose to drop those rows.

# %%
#drop the rows of type organization
df = df[df['Laureate Type'] != "Organization"]

# %%
df
# Out:
#      Year    Category                                           Prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 964  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965  2016       Peace                      The Nobel Peace Prize 2016
# 966  2016     Physics                 The Nobel Prize in Physics 2016
# 967  2016     Physics                 The Nobel Prize in Physics 2016
# 968  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             Motivation Prize Share  \
# 0    in recognition of the extraordinary services h...         1/1
# 1    in special recognition of his poetic compositi...         1/1
# 2    for his work on serum therapy, especially its ...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 964    for his discoveries of mechanisms for autophagy         1/1
# 965  for his resolute efforts to bring the country'...         1/1
# 966  for theoretical discoveries of topological pha...         1/2
# 967  for theoretical discoveries of topological pha...         1/4
# 968  for theoretical discoveries of topological pha...         1/4
#
#      Laureate ID Laureate Type                    Full Name  Birth Date  \
# 0            160    Individual  Jacobus Henricus van t Hoff  1852-08-30
# 1            569    Individual              Sully Prudhomme  1839-03-16
# 2            293    Individual       Emil Adolf von Behring  1854-03-15
# 3            462    Individual            Jean Henry Dunant  1828-05-08
# 4            463    Individual               Frederic Passy  1822-05-20
# ..           ...           ...                          ...         ...
# 964          927    Individual             Yoshinori Ohsumi  1945-02-09
# 965          934    Individual           Juan Manuel Santos  1951-08-10
# 966          928    Individual             David J Thouless  1934-09-21
# 967          929    Individual           F Duncan M Haldane  1951-09-14
# 968          930    Individual         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 964            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 965             Bogotá          Colombia  Male                            NaN
# 966           Bearsden    United Kingdom  Male       University of Washington
# 967             London    United Kingdom  Male           Princeton University
# 968           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Ch tenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 964             Tokyo                     Japan         NaN        NaN
# 965               NaN                       NaN         NaN        NaN
# 966       Seattle, WA  United States of America         NaN        NaN
# 967     Princeton, NJ  United States of America         NaN        NaN
# 968    Providence, RI  United States of America         NaN        NaN
#
#     Death Country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 964           NaN
# 965           NaN
# 966           NaN
# 967           NaN
# 968           NaN
#
# [939 rows x 18 columns]

# %%
# we can drop the Laureate Type column since it is the same for all rows (records).
df['Laureate Type'].nunique()
# Out:
# 1

# %%
# dropping the Laureate Type column
df = df.drop(['Laureate Type'], axis=1)
df
# Out:
#      Year    Category                                           Prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 964  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965  2016       Peace                      The Nobel Peace Prize 2016
# 966  2016     Physics                 The Nobel Prize in Physics 2016
# 967  2016     Physics                 The Nobel Prize in Physics 2016
# 968  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             Motivation Prize Share  \
# 0    in recognition of the extraordinary services h...         1/1
# 1    in special recognition of his poetic compositi...         1/1
# 2    for his work on serum therapy, especially its ...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 964    for his discoveries of mechanisms for autophagy         1/1
# 965  for his resolute efforts to bring the country'...         1/1
# 966  for theoretical discoveries of topological pha...         1/2
# 967  for theoretical discoveries of topological pha...         1/4
# 968  for theoretical discoveries of topological pha...         1/4
#
#      Laureate ID                    Full Name  Birth Date         Birth City  \
# 0            160  Jacobus Henricus van t Hoff  1852-08-30          Rotterdam
# 1            569              Sully Prudhomme  1839-03-16              Paris
# 2            293       Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3            462            Jean Henry Dunant  1828-05-08             Geneva
# 4            463               Frederic Passy  1822-05-20              Paris
# ..           ...                          ...         ...                ...
# 964          927             Yoshinori Ohsumi  1945-02-09            Fukuoka
# 965          934           Juan Manuel Santos  1951-08-10             Bogotá
# 966          928             David J Thouless  1934-09-21           Bearsden
# 967          929           F Duncan M Haldane  1951-09-14             London
# 968          930         J Michael Kosterlitz  1943-06-22           Aberdeen
#
#         Birth Country   Sex              Organization Name Organization City  \
# 0         Netherlands  Male              Berlin University            Berlin
# 1              France  Male                            NaN               NaN
# 2    Prussia (Poland)  Male             Marburg University           Marburg
# 3         Switzerland  Male                            NaN               NaN
# 4              France  Male                            NaN               NaN
# ..                ...   ...                            ...               ...
# 964             Japan  Male  Tokyo Institute of Technology             Tokyo
# 965          Colombia  Male                            NaN               NaN
# 966    United Kingdom  Male       University of Washington       Seattle, WA
# 967    United Kingdom  Male           Princeton University     Princeton, NJ
# 968    United Kingdom  Male               Brown University    Providence, RI
#
#          Organization Country  Death Date Death City Death Country
# 0                     Germany  1911-03-01     Berlin       Germany
# 1                         NaN  1907-09-07   Ch tenay        France
# 2                     Germany  1917-03-31    Marburg       Germany
# 3                         NaN  1910-10-30     Heiden   Switzerland
# 4                         NaN  1912-06-12      Paris        France
# ..                        ...         ...        ...           ...
# 964                     Japan         NaN        NaN           NaN
# 965                       NaN         NaN        NaN           NaN
# 966  United States of America         NaN        NaN           NaN
# 967  United States of America         NaN        NaN           NaN
# 968  United States of America         NaN        NaN           NaN
#
# [939 rows x 17 columns]

# %% [markdown]
# # Checking for other redundant attributes

# %% [markdown]
# <body>The <i>Prize</i> column holds information that's already present in two other columns (<i>Year</i> and <i>Category</i>). Therefore, since it's redundant, we decided to drop it as well.</body>

# %%
# dropping the Prize column
df = df.drop(['Prize'], axis=1)
df.head()
# Out:
#    Year    Category                                         Motivation  \
# 0  1901   Chemistry  in recognition of the extraordinary services h...
# 1  1901  Literature  in special recognition of his poetic compositi...
# 2  1901    Medicine  for his work on serum therapy, especially its ...
# 3  1901       Peace                                                NaN
# 4  1901       Peace                                                NaN
#
#   Prize Share  Laureate ID                    Full Name  Birth Date  \
# 0         1/1          160  Jacobus Henricus van t Hoff  1852-08-30
# 1         1/1          569              Sully Prudhomme  1839-03-16
# 2         1/1          293       Emil Adolf von Behring  1854-03-15
# 3         1/2          462            Jean Henry Dunant  1828-05-08
# 4         1/2          463               Frederic Passy  1822-05-20
#
#           Birth City     Birth Country   Sex   Organization Name  \
# 0          Rotterdam       Netherlands  Male   Berlin University
# 1              Paris            France  Male                 NaN
# 2  Hansdorf (Lawice)  Prussia (Poland)  Male  Marburg University
# 3             Geneva       Switzerland  Male                 NaN
# 4              Paris            France  Male                 NaN
#
#   Organization City Organization Country  Death Date Death City Death Country
# 0            Berlin              Germany  1911-03-01     Berlin       Germany
# 1               NaN                  NaN  1907-09-07   Ch tenay        France
# 2           Marburg              Germany  1917-03-31    Marburg       Germany
# 3               NaN                  NaN  1910-10-30     Heiden   Switzerland
# 4               NaN                  NaN  1912-06-12      Paris        France

# %% [markdown]
# <h1>Check missing <span style="font-style:italic">Birth Dates</span></h1>
# <body>Now that the data contains indivdual laureates only, let's check how many of them is missing the birth date, given that we have dropped the organization laureates which had missing birth dates as they were groups.</body>

# %%
newdf = df.copy()
newdf[newdf["Birth Date"].isnull()]
# Out:
#      Year   Category                                         Motivation  \
# 853  2009  Chemistry  for studies of the structure and function of t...
# 894  2011    Physics  for the discovery of the accelerating expansio...
# 895  2011    Physics  for the discovery of the accelerating expansio...
#
#     Prize Share  Laureate ID                 Full Name Birth Date  \
# 853         1/3          841  Venkatraman Ramakrishnan        NaN
# 894         1/2          864           Saul Perlmutter        NaN
# 895         1/2          864           Saul Perlmutter        NaN
#
#                   Birth City             Birth Country   Sex  \
# 853  Chidambaram, Tamil Nadu                     India  Male
# 894     Champaign-Urbana, IL  United States of America  Male
# 895     Champaign-Urbana, IL  United States of America  Male
#
#                          Organization Name Organization City  \
# 853    MRC Laboratory of Molecular Biology         Cambridge
# 894  Lawrence Berkeley National Laboratory      Berkeley, CA
# 895               University of California      Berkeley, CA
#
#          Organization Country Death Date Death City Death Country
# 853            United Kingdom        NaN        NaN           NaN
# 894  United States of America        NaN        NaN           NaN
# 895  United States of America        NaN        NaN           NaN

# %% [markdown]
# <h1> Retrieving Alternative Datasets</h1>
# <body>Since there are three missing values, a research was made to try and find another data set which might carry the birth date of those 3 winners. Hence, the data can be merged or achieved from the below dataset. This dataset was reterived from: <a>https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/AGAFAQ</a> </body>

# %%
df_alternative = pd.read_csv("./laureate.csv")
df_alternative.head()
# Out:
#    id       firstname    surname        born        died  \
# 0   1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1   2  Hendrik Antoon    Lorentz  1853-07-18  1928-02-04
# 2   3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3   4   Antoine Henri  Becquerel  1852-12-15  1908-08-25
# 4   5          Pierre      Curie  1859-05-15  1906-04-19
#
#              bornCountry bornCountryCode                bornCity  \
# 0  Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1        the Netherlands              NL                  Arnhem
# 2        the Netherlands              NL              Zonnemaire
# 3                 France              FR                   Paris
# 4                 France              FR                   Paris
#
#        diedCountry diedCountryCode   diedCity gender    year category  \
# 0          Germany              DE     Munich   male  1901.0  physics
# 1  the Netherlands              NL        NaN   male  1902.0  physics
# 2  the Netherlands              NL  Amsterdam   male  1902.0  physics
# 3           France              FR        NaN   male  1903.0  physics
# 4           France              FR      Paris   male  1903.0  physics
#
#   overallMotivation  share                                         motivation  \
# 0               NaN    1.0  "in recognition of the extraordinary services ...
# 1               NaN    2.0  "in recognition of the extraordinary service t...
# 2               NaN    2.0  "in recognition of the extraordinary service t...
# 3               NaN    2.0  "in recognition of the extraordinary services ...
# 4               NaN    4.0  "in recognition of the extraordinary services ...
#
#                                                 name       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# 2                               Amsterdam University  Amsterdam
# 3                                École Polytechnique      Paris
# 4  École municipale de physique et de chimie indu...      Paris
#
#            country
# 0          Germany
# 1  the Netherlands
# 2  the Netherlands
# 3           France
# 4           France

# %%
#checking the birthdates using the laureate id in the new data set
df_alternative[(df_alternative['id']==841)|(df_alternative['id']==864)]
# Out:
#       id    firstname       surname        born        died bornCountry  \
# 862  841  Venkatraman  Ramakrishnan  0000-00-00  0000-00-00       India
# 887  864         Saul    Perlmutter  0000-00-00  0000-00-00         USA
# 888  864         Saul    Perlmutter  0000-00-00  0000-00-00         USA
#
#     bornCountryCode                 bornCity diedCountry diedCountryCode  \
# 862              IN  Chidambaram, Tamil Nadu         NaN             NaN
# 887              US     Champaign-Urbana, IL         NaN             NaN
# 888              US     Champaign-Urbana, IL         NaN             NaN
#
#     diedCity gender    year   category overallMotivation  share  \
# 862      NaN   male  2009.0  chemistry               NaN    3.0
# 887      NaN   male  2011.0    physics               NaN    2.0
# 888      NaN   male  2011.0    physics               NaN    2.0
#
#                                             motivation  \
# 862  "for studies of the structure and function of ...
# 887  "for the discovery of the accelerating expansi...
# 888  "for the discovery of the accelerating expansi...
#
#                                       name          city         country
# 862    MRC Laboratory of Molecular Biology     Cambridge  United Kingdom
# 887  Lawrence Berkeley National Laboratory  Berkeley, CA             USA
# 888               University of California  Berkeley, CA             USA

# %% [markdown]
# <body> As shown above, the birth dates, <span style="font-style:italic">born</span>, and death dates, <span style="font-style:italic">died</span>, are assigned to a default zeros format. Indicating that the values are also missing. (BASMAAA) Therefore, the age will be calculated for the rest of the rows which have existing birth dates. Afterward, the age will be imputed for the 3 rows with missing birth dates values. </body>

# %% [markdown]
# WAIT FOR BASMA for normal age

# %% [markdown]
# <h1>Impute Winning Age</h1>
# <body>We find out that we have three missing values of the birth date and no missing values of the winning year <span style="font-style:italic">Year</span>, So we will create a new dataset with the birth date values without the nulls and compute the age of winning the prize then we will impute the missing values after adding the age column to our orginal dataset </body>

# %%
#new data set called Birth_Date, where the Birth Date null records were dropped
Birth_Date = df[['Laureate ID','Year','Birth Date', 'Death Date']]
Birth_Date = Birth_Date.dropna(axis=0, subset=['Birth Date'])
Birth_Date[Birth_Date["Death Date"].isnull()].sum()
# Out:
# Laureate ID                                               206188
# Year                                                      642045
# Birth Date     1922-09-221926-11-241928-04-061927-05-091929-0...
# Death Date                                                     0
# dtype: object

# %% [markdown]
# <h1> Extract the Birth Year</h1>
# Now we don't have any null values in the <span style="font-style:italic"> Birth Date</span> and the <span style="font-style:italic"> Year </span> column.
# Therefore, we only extract the year of birth from the <span style="font-style:italic">Birth Date</span> to be able to calculate the age of winning the nobel prize. Since, the<span style="font-style:italic"> Year</span> column has the winning year, rather than the date.

# %%
#The code below extracts the year from the date
Birth_Date["Birth Date"] = Birth_Date["Birth Date"].str.extract("(\d+)-", expand=False).astype(float)
Birth_Date.head(2)
# Out:
#    Laureate ID  Year  Birth Date  Death Date
# 0          160  1901      1852.0  1911-03-01
# 1          569  1901      1839.0  1907-09-07

# %% [markdown]
# <h1> Calculate the Winning Age</h1>
# 2- Calculate the winning age by subtracting the<span style="font-style:italic">Birth Date</span> column from the <span style="font-style:italic">Year</span> column. <br>
# 3- Create a column within the <span style="font-style:italic">Birth_Date</span> dataframe which will hold the calculated winning age

# %%
winning_age = Birth_Date["Year"] - Birth_Date["Birth Date"]
Birth_Date['Winning_age'] = winning_age
Birth_Date.head(5)
# Out:
#    Laureate ID  Year  Birth Date  Death Date  Winning_age
# 0          160  1901      1852.0  1911-03-01         49.0
# 1          569  1901      1839.0  1907-09-07         62.0
# 2          293  1901      1854.0  1917-03-31         47.0
# 3          462  1901      1828.0  1910-10-30         73.0
# 4          463  1901      1822.0  1912-06-12         79.0

# %% [markdown]
# Now we have the winning age of all our dataset records which had non null<span style="font-style:italic"> Birth Date</span> and we will add this column to our dataframe

# %%
df=df.copy()
df["Winning_age"] = winning_age
#check the missing winning age as a result of the birth date null values
display(df[df["Winning_age"].isnull()])
# Out:
#      Year   Category                                         Motivation  \
# 853  2009  Chemistry  for studies of the structure and function of t...
# 894  2011    Physics  for the discovery of the accelerating expansio...
# 895  2011    Physics  for the discovery of the accelerating expansio...
#
#     Prize Share  Laureate ID                 Full Name Birth Date  \
# 853         1/3          841  Venkatraman Ramakrishnan        NaN
# 894         1/2          864           Saul Perlmutter        NaN
# 895         1/2          864           Saul Perlmutter        NaN
#
#                   Birth City             Birth Country   Sex  \
# 853  Chidambaram, Tamil Nadu                     India  Male
# 894     Champaign-Urbana, IL  United States of America  Male
# 895     Champaign-Urbana, IL  United States of America  Male
#
#                          Organization Name Organization City  \
# 853    MRC Laboratory of Molecular Biology         Cambridge
# 894  Lawrence Berkeley National Laboratory      Berkeley, CA
# 895               University of California      Berkeley, CA
#
#          Organization Country Death Date Death City Death Country  Winning_age
# 853            United Kingdom        NaN        NaN           NaN          NaN
# 894  United States of America        NaN        NaN           NaN          NaN
# 895  United States of America        NaN        NaN           NaN          NaN

# %% [markdown]
# <h1> Impute the Missing Winning Age </h1>
# <body>Since we have three missing winning age as result of missing the <span style="font-style:italic"> Birth Date</span>, we will compute these values using the mean accorrding to the sex column.</body>

# %%
df=df.copy()
df["Winning_age"] = df.groupby("Sex")["Winning_age"].transform(lambda x: x.fillna(x.mean()))
#basma missing outliers

# %%
#waiting for basma
display(df[df["Death Date"].isnull()])
# Out:
#      Year   Category                                         Motivation  \
# 318  1957    Physics  for their penetrating investigation of the so-...
# 319  1957    Physics  for their penetrating investigation of the so-...
# 355  1962   Medicine  for their discoveries concerning the molecular...
# 393  1967  Chemistry  for their studies of extremely fast chemical r...
# 417  1969    Physics  for his contributions and discoveries concerni...
# ..    ...        ...                                                ...
# 964  2016   Medicine    for his discoveries of mechanisms for autophagy
# 965  2016      Peace  for his resolute efforts to bring the country'...
# 966  2016    Physics  for theoretical discoveries of topological pha...
# 967  2016    Physics  for theoretical discoveries of topological pha...
# 968  2016    Physics  for theoretical discoveries of topological pha...
#
#     Prize Share  Laureate ID             Full Name  Birth Date     Birth City  \
# 318         1/2           68        Chen Ning Yang  1922-09-22  Hofei, Anhwei
# 319         1/2           69     Tsung Dao T D Lee  1926-11-24       Shanghai
# 355         1/3          373    James Dewey Watson  1928-04-06    Chicago, IL
# 393         1/2          233         Manfred Eigen  1927-05-09         Bochum
# 417         1/1           90      Murray Gell Mann  1929-09-15   New York, NY
# ..          ...          ...                   ...         ...            ...
# 964         1/1          927      Yoshinori Ohsumi  1945-02-09        Fukuoka
# 965         1/1          934    Juan Manuel Santos  1951-08-10         Bogotá
# 966         1/2          928      David J Thouless  1934-09-21       Bearsden
# 967         1/4          929    F Duncan M Haldane  1951-09-14         London
# 968         1/4          930  J Michael Kosterlitz  1943-06-22       Aberdeen
#
#                 Birth Country   Sex  \
# 318                     China  Male
# 319                     China  Male
# 355  United States of America  Male
# 393                   Germany  Male
# 417  United States of America  Male
# ..                        ...   ...
# 964                     Japan  Male
# 965                  Colombia  Male
# 966            United Kingdom  Male
# 967            United Kingdom  Male
# 968            United Kingdom  Male
#
#                                 Organization Name Organization City  \
# 318                  Institute for Advanced Study     Princeton, NJ
# 319                           Columbia University      New York, NY
# 355                            Harvard University     Cambridge, MA
# 393  Max-Planck-Institut für Physikalische Chemie         Göttingen
# 417  California Institute of Technology (Caltech)      Pasadena, CA
# ..                                            ...               ...
# 964                 Tokyo Institute of Technology             Tokyo
# 965                                           NaN               NaN
# 966                      University of Washington       Seattle, WA
# 967                          Princeton University     Princeton, NJ
# 968                              Brown University    Providence, RI
#
#             Organization Country Death Date Death City Death Country  \
# 318     United States of America        NaN        NaN           NaN
# 319     United States of America        NaN        NaN           NaN
# 355     United States of America        NaN        NaN           NaN
# 393  Federal Republic of Germany        NaN        NaN           NaN
# 417     United States of America        NaN        NaN           NaN
# ..                           ...        ...        ...           ...
# 964                        Japan        NaN        NaN           NaN
# 965                          NaN        NaN        NaN           NaN
# 966     United States of America        NaN        NaN           NaN
# 967     United States of America        NaN        NaN           NaN
# 968     United States of America        NaN        NaN           NaN
#
#      Winning_age
# 318         35.0
# 319         31.0
# 355         34.0
# 393         40.0
# 417         40.0
# ..           ...
# 964         71.0
# 965         65.0
# 966         82.0
# 967         65.0
# 968         73.0
#
# [324 rows x 17 columns]

# %% [markdown]
# <h1>Check missing <span style="font-style:italic">Birth Cities</span></h1>
# <body>In the below code, the rows with missing birth city</body>

# %%
newdf[newdf["Birth City"].isnull()]
# Out:
#      Year    Category                                         Motivation  \
# 750  2001  Literature  for having united perceptive narrative and inc...
# 880  2010       Peace  for his long and non-violent struggle for fund...
#
#     Prize Share  Laureate ID                          Full Name  Birth Date  \
# 750         1/1          747  Sir Vidiadhar Surajprasad Naipaul  1932-08-17
# 880         1/1          855                         Liu Xiaobo  1955-12-28
#
#     Birth City Birth Country   Sex Organization Name Organization City  \
# 750        NaN      Trinidad  Male               NaN               NaN
# 880        NaN         China  Male               NaN               NaN
#
#     Organization Country Death Date Death City Death Country
# 750                  NaN        NaN        NaN           NaN
# 880                  NaN        NaN        NaN           NaN

# %%
#check if in the new data set we can retrieve birth city of the missing rows.
df_alternative[(df_alternative['id']==855)|(df_alternative['id']==747)]
# Out:
#       id                  firstname  surname        born        died  \
# 756  747  Sir Vidiadhar Surajprasad  Naipaul  1932-08-17  0000-00-00
# 878  855                        Liu   Xiaobo  1955-12-28  0000-00-00
#
#     bornCountry bornCountryCode bornCity diedCountry diedCountryCode diedCity  \
# 756    Trinidad              TT      NaN         NaN             NaN      NaN
# 878       China              CN      NaN         NaN             NaN      NaN
#
#     gender    year    category overallMotivation  share  \
# 756   male  2001.0  literature               NaN    1.0
# 878   male  2010.0       peace               NaN    1.0
#
#                                             motivation name city country
# 756  "for having united perceptive narrative and in...  NaN  NaN     NaN
# 878  "for his long and non-violent struggle for fun...  NaN  NaN     NaN

# %% [markdown]
# Since the new dataset does not contain the birth city,  <span style="font-style:italic"> bornCity </span>, for the two missing birth cities in the original dataset, no merge could be applied. Hence, the <span style="font-style:italic"> Birth City </span> mode will be used. Such that it is the mode of the city corresponding to the <span style="font-style:italic"> Birth Country </span>of the winner.

# %%
display(df[df["Birth Country"]=="China"])
# Out:
#      Year    Category                                         Motivation  \
# 313  1956     Physics  for their researches on semiconductors and the...
# 318  1957     Physics  for their penetrating investigation of the so-...
# 319  1957     Physics  for their penetrating investigation of the so-...
# 645  1992    Medicine  for their discoveries concerning reversible pr...
# 722  1998     Physics  for their discovery of a new form of quantum f...
# 736  2000  Literature  for an æuvre of universal validity, bitter ins...
# 867  2009     Physics  for groundbreaking achievements concerning the...
# 868  2009     Physics  for groundbreaking achievements concerning the...
# 872  2010   Chemistry  for palladium-catalyzed cross couplings in org...
# 880  2010       Peace  for his long and non-violent struggle for fund...
# 905  2012  Literature  who with hallucinatory realism merges folk tal...
# 954  2015    Medicine  for her discoveries concerning a novel therapy...
#
#     Prize Share  Laureate ID               Full Name  Birth Date  \
# 313         1/3           67  Walter Houser Brattain  1902-02-10
# 318         1/2           68          Chen Ning Yang  1922-09-22
# 319         1/2           69       Tsung Dao T D Lee  1926-11-24
# 645         1/2          446        Edmond H Fischer  1920-04-06
# 722         1/3          157           Daniel C Tsui  1939-02-28
# 736         1/1          734            Gao Xingjian  1940-01-04
# 867         1/2          838        Charles Kuen Kao  1933-11-04
# 868         1/2          838        Charles Kuen Kao  1933-11-04
# 872         1/3          852         Ei ichi Negishi  1935-07-14
# 880         1/1          855              Liu Xiaobo  1955-12-28
# 905         1/1          880                  Mo Yan  1955-02-02
# 954         1/2          918               Youyou Tu  1930-12-30
#
#           Birth City Birth Country     Sex  \
# 313             Amoy         China    Male
# 318    Hofei, Anhwei         China    Male
# 319         Shanghai         China    Male
# 645         Shanghai         China    Male
# 722            Henan         China    Male
# 736          Ganzhou         China    Male
# 867         Shanghai         China    Male
# 868         Shanghai         China    Male
# 872        Changchun         China    Male
# 880              NaN         China    Male
# 905            Gaomi         China    Male
# 954  Zhejiang Ningbo         China  Female
#
#                                  Organization Name   Organization City  \
# 313                    Bell Telephone Laboratories     Murray Hill, NJ
# 318                   Institute for Advanced Study       Princeton, NJ
# 319                            Columbia University        New York, NY
# 645                       University of Washington         Seattle, WA
# 722                           Princeton University       Princeton, NJ
# 736                                            NaN                 NaN
# 867        Standard Telecommunication Laboratories              Harlow
# 868                Chinese University of Hong Kong           Hong Kong
# 872                              Purdue University  West Lafayette, IN
# 880                                            NaN                 NaN
# 905                                            NaN                 NaN
# 954  China Academy of Traditional Chinese Medicine             Beijing
#
#          Organization Country  Death Date  Death City  \
# 313  United States of America  1987-10-13  Seattle WA
# 318  United States of America         NaN         NaN
# 319  United States of America         NaN         NaN
# 645  United States of America         NaN         NaN
# 722  United States of America         NaN         NaN
# 736                       NaN         NaN         NaN
# 867            United Kingdom         NaN         NaN
# 868                     China         NaN         NaN
# 872  United States of America         NaN         NaN
# 880                       NaN         NaN         NaN
# 905                       NaN         NaN         NaN
# 954                     China         NaN         NaN
#
#                 Death Country  Winning_age
# 313  United States of America         54.0
# 318                       NaN         35.0
# 319                       NaN         31.0
# 645                       NaN         72.0
# 722                       NaN         59.0
# 736                       NaN         60.0
# 867                       NaN         76.0
# 868                       NaN         76.0
# 872                       NaN         75.0
# 880                       NaN         55.0
# 905                       NaN         57.0
# 954                       NaN         85.0

# %%
display(df[df["Birth Country"]=="Trinidad"])
# Out:
#      Year    Category                                         Motivation  \
# 750  2001  Literature  for having united perceptive narrative and inc...
#
#     Prize Share  Laureate ID                          Full Name  Birth Date  \
# 750         1/1          747  Sir Vidiadhar Surajprasad Naipaul  1932-08-17
#
#     Birth City Birth Country   Sex Organization Name Organization City  \
# 750        NaN      Trinidad  Male               NaN               NaN
#
#     Organization Country Death Date Death City Death Country  Winning_age
# 750                  NaN        NaN        NaN           NaN         69.0

# %% [markdown]
# Since only one record has the <i>Birth Country: Trinidad</i>, a manual insertion of the <i>Birth City</i> of that record will be done

# %%
df = df.copy()  # Ensuring a copy is made
df.loc[df['Birth Country'] == "Trinidad", 'Birth City'] = 'Chaguanas Borough Corporation'

# %%
 #df.groupby('Birth Country')['Birth City'].transform(lambda x: x.fillna(x.mode()))
df[(df["Birth Country"]=="China")|(df["Birth Country"]=="Trinidad")] 
df["Birth City"]=df.groupby('Birth Country')['Birth City'].transform(lambda x: x.fillna(x.mode()[0]))

 #df.groupby("Birth Country")["Birth City"]

# %%
display(df[df["Birth Country"]=="China"])
# Out:
#      Year    Category                                         Motivation  \
# 313  1956     Physics  for their researches on semiconductors and the...
# 318  1957     Physics  for their penetrating investigation of the so-...
# 319  1957     Physics  for their penetrating investigation of the so-...
# 645  1992    Medicine  for their discoveries concerning reversible pr...
# 722  1998     Physics  for their discovery of a new form of quantum f...
# 736  2000  Literature  for an æuvre of universal validity, bitter ins...
# 867  2009     Physics  for groundbreaking achievements concerning the...
# 868  2009     Physics  for groundbreaking achievements concerning the...
# 872  2010   Chemistry  for palladium-catalyzed cross couplings in org...
# 880  2010       Peace  for his long and non-violent struggle for fund...
# 905  2012  Literature  who with hallucinatory realism merges folk tal...
# 954  2015    Medicine  for her discoveries concerning a novel therapy...
#
#     Prize Share  Laureate ID               Full Name  Birth Date  \
# 313         1/3           67  Walter Houser Brattain  1902-02-10
# 318         1/2           68          Chen Ning Yang  1922-09-22
# 319         1/2           69       Tsung Dao T D Lee  1926-11-24
# 645         1/2          446        Edmond H Fischer  1920-04-06
# 722         1/3          157           Daniel C Tsui  1939-02-28
# 736         1/1          734            Gao Xingjian  1940-01-04
# 867         1/2          838        Charles Kuen Kao  1933-11-04
# 868         1/2          838        Charles Kuen Kao  1933-11-04
# 872         1/3          852         Ei ichi Negishi  1935-07-14
# 880         1/1          855              Liu Xiaobo  1955-12-28
# 905         1/1          880                  Mo Yan  1955-02-02
# 954         1/2          918               Youyou Tu  1930-12-30
#
#           Birth City Birth Country     Sex  \
# 313             Amoy         China    Male
# 318    Hofei, Anhwei         China    Male
# 319         Shanghai         China    Male
# 645         Shanghai         China    Male
# 722            Henan         China    Male
# 736          Ganzhou         China    Male
# 867         Shanghai         China    Male
# 868         Shanghai         China    Male
# 872        Changchun         China    Male
# 880         Shanghai         China    Male
# 905            Gaomi         China    Male
# 954  Zhejiang Ningbo         China  Female
#
#                                  Organization Name   Organization City  \
# 313                    Bell Telephone Laboratories     Murray Hill, NJ
# 318                   Institute for Advanced Study       Princeton, NJ
# 319                            Columbia University        New York, NY
# 645                       University of Washington         Seattle, WA
# 722                           Princeton University       Princeton, NJ
# 736                                            NaN                 NaN
# 867        Standard Telecommunication Laboratories              Harlow
# 868                Chinese University of Hong Kong           Hong Kong
# 872                              Purdue University  West Lafayette, IN
# 880                                            NaN                 NaN
# 905                                            NaN                 NaN
# 954  China Academy of Traditional Chinese Medicine             Beijing
#
#          Organization Country  Death Date  Death City  \
# 313  United States of America  1987-10-13  Seattle WA
# 318  United States of America         NaN         NaN
# 319  United States of America         NaN         NaN
# 645  United States of America         NaN         NaN
# 722  United States of America         NaN         NaN
# 736                       NaN         NaN         NaN
# 867            United Kingdom         NaN         NaN
# 868                     China         NaN         NaN
# 872  United States of America         NaN         NaN
# 880                       NaN         NaN         NaN
# 905                       NaN         NaN         NaN
# 954                     China         NaN         NaN
#
#                 Death Country  Winning_age
# 313  United States of America         54.0
# 318                       NaN         35.0
# 319                       NaN         31.0
# 645                       NaN         72.0
# 722                       NaN         59.0
# 736                       NaN         60.0
# 867                       NaN         76.0
# 868                       NaN         76.0
# 872                       NaN         75.0
# 880                       NaN         55.0
# 905                       NaN         57.0
# 954                       NaN         85.0

# %% [markdown]
# <h1>Imputing the missing values of the <i>Motivation</i> attribute</h1><br>
# <body>There now exists 69 missing values in the <i>Motivation</i> column.<br><br> Therefore, we will try to find another dataset which contains those values. If that is the case, a merge between the two datasets is to be performed.</body>

# %%
df_motivation_nulls = df['Motivation'].isnull().sum()
df_motivation_nulls
# Out:
# 69

# %% [markdown]
# <body>A dataset was found containing a <i>Motivation</i> attribute which could be used to fill in the missing values in the original dataset.</body>

# %%
# Reading the data from the dataset found, named 'nobel'
nobel_data = pd.read_csv("nobel.csv")
nobel_data.isnull().sum()
# Out:
# Year               0
# Category           0
# Name               0
# Birthdate          0
# Birth Place        5
# County             0
# Residence          4
# Role/Affiliate    24
# Field/Language     0
# Prize Name         0
# Motivation         0
# dtype: int64

# %% [markdown]
# <body>No missing values for <i>Motivation</i> in the <i>nobel_data</i> dataset, so can be used to impute missing values of <i>Motivation</i> in our original dataset, to be able to use this attribute in our analysis.</body>

# %%
nullMotivation = df[df['Motivation'].isnull()]
nullMotivation
# Out:
#      Year Category Motivation Prize Share  Laureate ID              Full Name  \
# 3    1901    Peace        NaN         1/2          462      Jean Henry Dunant
# 4    1901    Peace        NaN         1/2          463         Frederic Passy
# 9    1902    Peace        NaN         1/2          464          Elie Ducommun
# 10   1902    Peace        NaN         1/2          465   Charles Albert Gobat
# 16   1903    Peace        NaN         1/1          466  William Randal Cremer
# ..    ...      ...        ...         ...          ...                    ...
# 553  1982    Peace        NaN         1/2          543            Alva Myrdal
# 554  1982    Peace        NaN         1/2          544  Alfonso Garc a Robles
# 560  1983    Peace        NaN         1/1          545            Lech Walesa
# 569  1984    Peace        NaN         1/1          546     Desmond Mpilo Tutu
# 587  1986    Peace        NaN         1/1          548            Elie Wiesel
#
#      Birth Date  Birth City   Birth Country     Sex Organization Name  \
# 3    1828-05-08      Geneva     Switzerland    Male               NaN
# 4    1822-05-20       Paris          France    Male               NaN
# 9    1833-02-19      Geneva     Switzerland    Male               NaN
# 10   1843-05-21    Tramelan     Switzerland    Male               NaN
# 16   1828-03-18     Fareham  United Kingdom    Male               NaN
# ..          ...         ...             ...     ...               ...
# 553  1902-01-31     Uppsala          Sweden  Female               NaN
# 554  1911-03-20      Zamora          Mexico    Male               NaN
# 560  1943-09-29      Popowo          Poland    Male               NaN
# 569  1931-10-07  Klerksdorp    South Africa    Male               NaN
# 587  1928-09-30      Sighet         Romania    Male               NaN
#
#     Organization City Organization Country  Death Date   Death City  \
# 3                 NaN                  NaN  1910-10-30       Heiden
# 4                 NaN                  NaN  1912-06-12        Paris
# 9                 NaN                  NaN  1906-12-07         Bern
# 10                NaN                  NaN  1914-03-16         Bern
# 16                NaN                  NaN  1908-07-22       London
# ..                ...                  ...         ...          ...
# 553               NaN                  NaN  1986-02-01    Stockholm
# 554               NaN                  NaN  1991-09-02  Mexico City
# 560               NaN                  NaN         NaN          NaN
# 569               NaN                  NaN         NaN          NaN
# 587               NaN                  NaN  2016-07-02  New York NY
#
#                 Death Country  Winning_age
# 3                 Switzerland         73.0
# 4                      France         79.0
# 9                 Switzerland         69.0
# 10                Switzerland         59.0
# 16             United Kingdom         75.0
# ..                        ...          ...
# 553                    Sweden         80.0
# 554                    Mexico         71.0
# 560                       NaN         40.0
# 569                       NaN         53.0
# 587  United States of America         58.0
#
# [69 rows x 17 columns]

# %%
# Filling the missing values for 'Motivation' by merging the dataset containing records with a null Motivation value 
# (nullMotivation), with the external dataset (nobel_data), using the winner's name for the merge

merged_df = pd.merge(nullMotivation, nobel_data, left_on="Full Name", right_on="Name", how='left').drop(['Year_y', 
'Category_y', 'Motivation_x', 'Name', 'Birthdate', 'Birth Place', 'County', 'Residence', 'Role/Affiliate', 'Field/Language', 
'Prize Name'], axis=1)

merged_df.rename(columns = {'Year_x':'Year', 'Category_x':'Category', 'Motivation_y':'Motivation'}, inplace = True)

merged_df
# Out:
#     Year Category Prize Share  Laureate ID              Full Name  Birth Date  \
# 0   1901    Peace         1/2          462      Jean Henry Dunant  1828-05-08
# 1   1901    Peace         1/2          463         Frederic Passy  1822-05-20
# 2   1902    Peace         1/2          464          Elie Ducommun  1833-02-19
# 3   1902    Peace         1/2          465   Charles Albert Gobat  1843-05-21
# 4   1903    Peace         1/1          466  William Randal Cremer  1828-03-18
# ..   ...      ...         ...          ...                    ...         ...
# 65  1982    Peace         1/2          543            Alva Myrdal  1902-01-31
# 66  1982    Peace         1/2          544  Alfonso Garc a Robles  1911-03-20
# 67  1983    Peace         1/1          545            Lech Walesa  1943-09-29
# 68  1984    Peace         1/1          546     Desmond Mpilo Tutu  1931-10-07
# 69  1986    Peace         1/1          548            Elie Wiesel  1928-09-30
#
#     Birth City   Birth Country     Sex Organization Name Organization City  \
# 0       Geneva     Switzerland    Male               NaN               NaN
# 1        Paris          France    Male               NaN               NaN
# 2       Geneva     Switzerland    Male               NaN               NaN
# 3     Tramelan     Switzerland    Male               NaN               NaN
# 4      Fareham  United Kingdom    Male               NaN               NaN
# ..         ...             ...     ...               ...               ...
# 65     Uppsala          Sweden  Female               NaN               NaN
# 66      Zamora          Mexico    Male               NaN               NaN
# 67      Popowo          Poland    Male               NaN               NaN
# 68  Klerksdorp    South Africa    Male               NaN               NaN
# 69      Sighet         Romania    Male               NaN               NaN
#
#    Organization Country  Death Date   Death City             Death Country  \
# 0                   NaN  1910-10-30       Heiden               Switzerland
# 1                   NaN  1912-06-12        Paris                    France
# 2                   NaN  1906-12-07         Bern               Switzerland
# 3                   NaN  1914-03-16         Bern               Switzerland
# 4                   NaN  1908-07-22       London            United Kingdom
# ..                  ...         ...          ...                       ...
# 65                  NaN  1986-02-01    Stockholm                    Sweden
# 66                  NaN  1991-09-02  Mexico City                    Mexico
# 67                  NaN         NaN          NaN                       NaN
# 68                  NaN         NaN          NaN                       NaN
# 69                  NaN  2016-07-02  New York NY  United States of America
#
#     Winning_age                                         Motivation
# 0          73.0  The Nobel Peace Prize 1901 was awarded jointly...
# 1          79.0                                                NaN
# 2          69.0                                                NaN
# 3          59.0  The Nobel Peace Prize 1902 was awarded jointly...
# 4          75.0  The Nobel Peace Prize 1903 was awarded to Rand...
# ..          ...                                                ...
# 65         80.0  The Nobel Peace Prize 1982 was awarded jointly...
# 66         71.0                                                NaN
# 67         40.0  The Nobel Peace Prize 1983 was awarded to Lech...
# 68         53.0  The Nobel Peace Prize 1984 was awarded to Desm...
# 69         58.0  The Nobel Peace Prize 1986 was awarded to Elie...
#
# [70 rows x 17 columns]

# %%
# Dropping the unneeded columns for a second merge with the original dataset

merged_df = merged_df.drop(['Year', 'Category', 'Prize Share', 'Laureate ID', 'Birth Date', 'Birth City', 'Birth Country', 
                            'Sex', 'Organization Name', 'Organization City', 'Organization Country', 'Death Date', 
                            'Death City', 'Death Country', 'Winning_age'], axis=1)

merged_df
# Out:
#                 Full Name                                         Motivation
# 0       Jean Henry Dunant  The Nobel Peace Prize 1901 was awarded jointly...
# 1          Frederic Passy                                                NaN
# 2           Elie Ducommun                                                NaN
# 3    Charles Albert Gobat  The Nobel Peace Prize 1902 was awarded jointly...
# 4   William Randal Cremer  The Nobel Peace Prize 1903 was awarded to Rand...
# ..                    ...                                                ...
# 65            Alva Myrdal  The Nobel Peace Prize 1982 was awarded jointly...
# 66  Alfonso Garc a Robles                                                NaN
# 67            Lech Walesa  The Nobel Peace Prize 1983 was awarded to Lech...
# 68     Desmond Mpilo Tutu  The Nobel Peace Prize 1984 was awarded to Desm...
# 69            Elie Wiesel  The Nobel Peace Prize 1986 was awarded to Elie...
#
# [70 rows x 2 columns]

# %%
# Merging the dataset containing the filled Motivation values from the external dataset (merged_df) with our original dataset
df = pd.merge(df, merged_df, on="Full Name", how='left')
df
# Out:
#      Year    Category                                       Motivation_x  \
# 0    1901   Chemistry  in recognition of the extraordinary services h...
# 1    1901  Literature  in special recognition of his poetic compositi...
# 2    1901    Medicine  for his work on serum therapy, especially its ...
# 3    1901       Peace                                                NaN
# 4    1901       Peace                                                NaN
# ..    ...         ...                                                ...
# 936  2016    Medicine    for his discoveries of mechanisms for autophagy
# 937  2016       Peace  for his resolute efforts to bring the country'...
# 938  2016     Physics  for theoretical discoveries of topological pha...
# 939  2016     Physics  for theoretical discoveries of topological pha...
# 940  2016     Physics  for theoretical discoveries of topological pha...
#
#     Prize Share  Laureate ID                    Full Name  Birth Date  \
# 0           1/1          160  Jacobus Henricus van t Hoff  1852-08-30
# 1           1/1          569              Sully Prudhomme  1839-03-16
# 2           1/1          293       Emil Adolf von Behring  1854-03-15
# 3           1/2          462            Jean Henry Dunant  1828-05-08
# 4           1/2          463               Frederic Passy  1822-05-20
# ..          ...          ...                          ...         ...
# 936         1/1          927             Yoshinori Ohsumi  1945-02-09
# 937         1/1          934           Juan Manuel Santos  1951-08-10
# 938         1/2          928             David J Thouless  1934-09-21
# 939         1/4          929           F Duncan M Haldane  1951-09-14
# 940         1/4          930         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 936            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 937             Bogotá          Colombia  Male                            NaN
# 938           Bearsden    United Kingdom  Male       University of Washington
# 939             London    United Kingdom  Male           Princeton University
# 940           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Ch tenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 936             Tokyo                     Japan         NaN        NaN
# 937               NaN                       NaN         NaN        NaN
# 938       Seattle, WA  United States of America         NaN        NaN
# 939     Princeton, NJ  United States of America         NaN        NaN
# 940    Providence, RI  United States of America         NaN        NaN
#
#     Death Country  Winning_age  \
# 0         Germany         49.0
# 1          France         62.0
# 2         Germany         47.0
# 3     Switzerland         73.0
# 4          France         79.0
# ..            ...          ...
# 936           NaN         71.0
# 937           NaN         65.0
# 938           NaN         82.0
# 939           NaN         65.0
# 940           NaN         73.0
#
#                                           Motivation_y
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    The Nobel Peace Prize 1901 was awarded jointly...
# 4                                                  NaN
# ..                                                 ...
# 936                                                NaN
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940                                                NaN
#
# [941 rows x 18 columns]

# %%
df['Motivation_x'] = df['Motivation_x'].fillna(df['Motivation_y'])
df
# Out:
#      Year    Category                                       Motivation_x  \
# 0    1901   Chemistry  in recognition of the extraordinary services h...
# 1    1901  Literature  in special recognition of his poetic compositi...
# 2    1901    Medicine  for his work on serum therapy, especially its ...
# 3    1901       Peace  The Nobel Peace Prize 1901 was awarded jointly...
# 4    1901       Peace                                                NaN
# ..    ...         ...                                                ...
# 936  2016    Medicine    for his discoveries of mechanisms for autophagy
# 937  2016       Peace  for his resolute efforts to bring the country'...
# 938  2016     Physics  for theoretical discoveries of topological pha...
# 939  2016     Physics  for theoretical discoveries of topological pha...
# 940  2016     Physics  for theoretical discoveries of topological pha...
#
#     Prize Share  Laureate ID                    Full Name  Birth Date  \
# 0           1/1          160  Jacobus Henricus van t Hoff  1852-08-30
# 1           1/1          569              Sully Prudhomme  1839-03-16
# 2           1/1          293       Emil Adolf von Behring  1854-03-15
# 3           1/2          462            Jean Henry Dunant  1828-05-08
# 4           1/2          463               Frederic Passy  1822-05-20
# ..          ...          ...                          ...         ...
# 936         1/1          927             Yoshinori Ohsumi  1945-02-09
# 937         1/1          934           Juan Manuel Santos  1951-08-10
# 938         1/2          928             David J Thouless  1934-09-21
# 939         1/4          929           F Duncan M Haldane  1951-09-14
# 940         1/4          930         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 936            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 937             Bogotá          Colombia  Male                            NaN
# 938           Bearsden    United Kingdom  Male       University of Washington
# 939             London    United Kingdom  Male           Princeton University
# 940           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Ch tenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 936             Tokyo                     Japan         NaN        NaN
# 937               NaN                       NaN         NaN        NaN
# 938       Seattle, WA  United States of America         NaN        NaN
# 939     Princeton, NJ  United States of America         NaN        NaN
# 940    Providence, RI  United States of America         NaN        NaN
#
#     Death Country  Winning_age  \
# 0         Germany         49.0
# 1          France         62.0
# 2         Germany         47.0
# 3     Switzerland         73.0
# 4          France         79.0
# ..            ...          ...
# 936           NaN         71.0
# 937           NaN         65.0
# 938           NaN         82.0
# 939           NaN         65.0
# 940           NaN         73.0
#
#                                           Motivation_y
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    The Nobel Peace Prize 1901 was awarded jointly...
# 4                                                  NaN
# ..                                                 ...
# 936                                                NaN
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940                                                NaN
#
# [941 rows x 18 columns]

# %%
df = df.drop(['Motivation_y'], axis=1)
df.rename(columns = {'Motivation_x':'Motivation'}, inplace = True)
df
# Out:
#      Year    Category                                         Motivation  \
# 0    1901   Chemistry  in recognition of the extraordinary services h...
# 1    1901  Literature  in special recognition of his poetic compositi...
# 2    1901    Medicine  for his work on serum therapy, especially its ...
# 3    1901       Peace  The Nobel Peace Prize 1901 was awarded jointly...
# 4    1901       Peace                                                NaN
# ..    ...         ...                                                ...
# 936  2016    Medicine    for his discoveries of mechanisms for autophagy
# 937  2016       Peace  for his resolute efforts to bring the country'...
# 938  2016     Physics  for theoretical discoveries of topological pha...
# 939  2016     Physics  for theoretical discoveries of topological pha...
# 940  2016     Physics  for theoretical discoveries of topological pha...
#
#     Prize Share  Laureate ID                    Full Name  Birth Date  \
# 0           1/1          160  Jacobus Henricus van t Hoff  1852-08-30
# 1           1/1          569              Sully Prudhomme  1839-03-16
# 2           1/1          293       Emil Adolf von Behring  1854-03-15
# 3           1/2          462            Jean Henry Dunant  1828-05-08
# 4           1/2          463               Frederic Passy  1822-05-20
# ..          ...          ...                          ...         ...
# 936         1/1          927             Yoshinori Ohsumi  1945-02-09
# 937         1/1          934           Juan Manuel Santos  1951-08-10
# 938         1/2          928             David J Thouless  1934-09-21
# 939         1/4          929           F Duncan M Haldane  1951-09-14
# 940         1/4          930         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 936            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 937             Bogotá          Colombia  Male                            NaN
# 938           Bearsden    United Kingdom  Male       University of Washington
# 939             London    United Kingdom  Male           Princeton University
# 940           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Ch tenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 936             Tokyo                     Japan         NaN        NaN
# 937               NaN                       NaN         NaN        NaN
# 938       Seattle, WA  United States of America         NaN        NaN
# 939     Princeton, NJ  United States of America         NaN        NaN
# 940    Providence, RI  United States of America         NaN        NaN
#
#     Death Country  Winning_age
# 0         Germany         49.0
# 1          France         62.0
# 2         Germany         47.0
# 3     Switzerland         73.0
# 4          France         79.0
# ..            ...          ...
# 936           NaN         71.0
# 937           NaN         65.0
# 938           NaN         82.0
# 939           NaN         65.0
# 940           NaN         73.0
#
# [941 rows x 17 columns]

# %%
# Checking for missing values after performing the merge
df[df['Motivation'].isnull()].shape[0]
# Out:
# 21

# %% [markdown]
# There are 21 missing values for <i>Motivation</i> after merging, meaning that records for these winners were not found in the external dataset used.<br><br>
#
# To fill these missing values, a value of <i>'Not Specified'</i> could be used, since no values for the <i>Motivation</i> were found for these records.

# %%
df['Motivation'] = df['Motivation'].fillna('Not Specified')
df[df['Motivation'].isnull()].shape[0]
# Out:
# 0

# %% [markdown]
# <body>There are no longer missing values in the <i>'Motivation'</i> column.</body>

# %% [markdown]
# <h1> Imputing the missing values of the <i>Organization Name</i> attribute </h1>

# %% [markdown]
# Even though we removed records where the <i>Laureate Type</i> is <i>Organization</i>, <i>Individuals</i> are still considered to have an Organization/Institute/University to which they belong, which is represented by the <i>Organization Name</i> column. However, we have missing values in that column.

# %%
df_nulls = df.isnull().sum()
df_nulls 

# There are 217 records with missing Organization Name
# Out:
# Year                      0
# Category                  0
# Motivation                0
# Prize Share               0
# Laureate ID               0
# Full Name                 0
# Birth Date                3
# Birth City                0
# Birth Country             0
# Sex                       0
# Organization Name       217
# Organization City       223
# Organization Country    223
# Death Date              324
# Death City              342
# Death Country           336
# Winning_age               0
# dtype: int64

# %% [markdown]
# <body>The previous dataset, named <i>nobel_data</i> was found to also contain a <i>Role/Affiliate</i> attribute which can be used to fill in the missing values in our original dataset.</body>

# %%
nullOrganization = df[df['Organization Name'].isnull()]

# %%
# Filling the missing values for 'Organization Name' by merging the dataset containing records with a null Organization Name 
# value (nullOrganization), with the external dataset (nobel_data), using the winner's name for the merge

merged_df = pd.merge(nullOrganization, nobel_data, left_on="Full Name", right_on="Name", how='left').drop(['Year_y', 
'Category_y', 'Motivation_y', 'Name', 'Birthdate', 'Birth Place', 'County', 'Residence', 'Field/Language', 'Prize Name'], 
axis=1)

merged_df.rename(columns = {'Year_x':'Year', 'Category_x':'Category', 'Motivation_x':'Motivation'}, inplace = True)

merged_df
# Out:
#      Year    Category                                         Motivation  \
# 0    1901  Literature  in special recognition of his poetic compositi...
# 1    1901       Peace  The Nobel Peace Prize 1901 was awarded jointly...
# 2    1901       Peace                                      Not Specified
# 3    1902  Literature  the greatest living master of the art of histo...
# 4    1902       Peace                                      Not Specified
# ..    ...         ...                                                ...
# 212  2014       Peace  for their struggle against the suppression of ...
# 213  2014       Peace  for their struggle against the suppression of ...
# 214  2015  Literature  for her polyphonic writings, a monument to suf...
# 215  2016  Literature  for having created new poetic expressions with...
# 216  2016       Peace  for his resolute efforts to bring the country'...
#
#     Prize Share  Laureate ID                           Full Name  Birth Date  \
# 0           1/1          569                     Sully Prudhomme  1839-03-16
# 1           1/2          462                   Jean Henry Dunant  1828-05-08
# 2           1/2          463                      Frederic Passy  1822-05-20
# 3           1/1          571  Christian Matthias Theodor Mommsen  1817-11-30
# 4           1/2          464                       Elie Ducommun  1833-02-19
# ..          ...          ...                                 ...         ...
# 212         1/2          913                   Kailash Satyarthi  1954-01-11
# 213         1/2          914                    Malala Yousafzai  1997-07-12
# 214         1/1          924                 Svetlana Alexievich  1948-05-31
# 215         1/1          937                           Bob Dylan  1941-05-24
# 216         1/1          934                  Juan Manuel Santos  1951-08-10
#
#           Birth City             Birth Country     Sex Organization Name  \
# 0              Paris                    France    Male               NaN
# 1             Geneva               Switzerland    Male               NaN
# 2              Paris                    France    Male               NaN
# 3            Garding       Schleswig (Germany)    Male               NaN
# 4             Geneva               Switzerland    Male               NaN
# ..               ...                       ...     ...               ...
# 212          Vidisha                     India    Male               NaN
# 213          Mingora                  Pakistan  Female               NaN
# 214  Ivano-Frankivsk                   Ukraine  Female               NaN
# 215       Duluth, MN  United States of America    Male               NaN
# 216           Bogotá                  Colombia    Male               NaN
#
#     Organization City Organization Country  Death Date      Death City  \
# 0                 NaN                  NaN  1907-09-07        Ch tenay
# 1                 NaN                  NaN  1910-10-30          Heiden
# 2                 NaN                  NaN  1912-06-12           Paris
# 3                 NaN                  NaN  1903-11-01  Charlottenburg
# 4                 NaN                  NaN  1906-12-07            Bern
# ..                ...                  ...         ...             ...
# 212               NaN                  NaN         NaN             NaN
# 213               NaN                  NaN         NaN             NaN
# 214               NaN                  NaN         NaN             NaN
# 215               NaN                  NaN         NaN             NaN
# 216               NaN                  NaN         NaN             NaN
#
#     Death Country  Winning_age  \
# 0          France         62.0
# 1     Switzerland         73.0
# 2          France         79.0
# 3         Germany         85.0
# 4     Switzerland         69.0
# ..            ...          ...
# 212           NaN         60.0
# 213           NaN         17.0
# 214           NaN         67.0
# 215           NaN         75.0
# 216           NaN         65.0
#
#                                         Role/Affiliate
# 0                                              No Data
# 1     Originator Geneva Convention (Convention de G...
# 2                                                  NaN
# 3                                              No Data
# 4                                                  NaN
# ..                                                 ...
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
#
# [217 rows x 18 columns]

# %%
# Dropping the unneeded columns for a second merge with the original dataset

merged_df = merged_df.drop(['Year', 'Category', 'Motivation', 'Prize Share', 'Laureate ID', 'Birth Date', 'Birth City', 
                            'Birth Country', 'Sex', 'Organization Name', 'Organization City', 'Organization Country', 
                            'Death Date', 'Death City', 'Death Country', 'Winning_age'], axis=1)

merged_df
# Out:
#                               Full Name  \
# 0                       Sully Prudhomme
# 1                     Jean Henry Dunant
# 2                        Frederic Passy
# 3    Christian Matthias Theodor Mommsen
# 4                         Elie Ducommun
# ..                                  ...
# 212                   Kailash Satyarthi
# 213                    Malala Yousafzai
# 214                 Svetlana Alexievich
# 215                           Bob Dylan
# 216                  Juan Manuel Santos
#
#                                         Role/Affiliate
# 0                                              No Data
# 1     Originator Geneva Convention (Convention de G...
# 2                                                  NaN
# 3                                              No Data
# 4                                                  NaN
# ..                                                 ...
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
#
# [217 rows x 2 columns]

# %%
# Merging the dataset containing the filled Organization Name values from the external dataset (merged_df) with our original 
# dataset
df = pd.merge(df, merged_df, on="Full Name", how='left')
df
# Out:
#      Year    Category                                         Motivation  \
# 0    1901   Chemistry  in recognition of the extraordinary services h...
# 1    1901  Literature  in special recognition of his poetic compositi...
# 2    1901    Medicine  for his work on serum therapy, especially its ...
# 3    1901       Peace  The Nobel Peace Prize 1901 was awarded jointly...
# 4    1901       Peace                                      Not Specified
# ..    ...         ...                                                ...
# 936  2016    Medicine    for his discoveries of mechanisms for autophagy
# 937  2016       Peace  for his resolute efforts to bring the country'...
# 938  2016     Physics  for theoretical discoveries of topological pha...
# 939  2016     Physics  for theoretical discoveries of topological pha...
# 940  2016     Physics  for theoretical discoveries of topological pha...
#
#     Prize Share  Laureate ID                    Full Name  Birth Date  \
# 0           1/1          160  Jacobus Henricus van t Hoff  1852-08-30
# 1           1/1          569              Sully Prudhomme  1839-03-16
# 2           1/1          293       Emil Adolf von Behring  1854-03-15
# 3           1/2          462            Jean Henry Dunant  1828-05-08
# 4           1/2          463               Frederic Passy  1822-05-20
# ..          ...          ...                          ...         ...
# 936         1/1          927             Yoshinori Ohsumi  1945-02-09
# 937         1/1          934           Juan Manuel Santos  1951-08-10
# 938         1/2          928             David J Thouless  1934-09-21
# 939         1/4          929           F Duncan M Haldane  1951-09-14
# 940         1/4          930         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 936            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 937             Bogotá          Colombia  Male                            NaN
# 938           Bearsden    United Kingdom  Male       University of Washington
# 939             London    United Kingdom  Male           Princeton University
# 940           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Ch tenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 936             Tokyo                     Japan         NaN        NaN
# 937               NaN                       NaN         NaN        NaN
# 938       Seattle, WA  United States of America         NaN        NaN
# 939     Princeton, NJ  United States of America         NaN        NaN
# 940    Providence, RI  United States of America         NaN        NaN
#
#     Death Country  Winning_age  \
# 0         Germany         49.0
# 1          France         62.0
# 2         Germany         47.0
# 3     Switzerland         73.0
# 4          France         79.0
# ..            ...          ...
# 936           NaN         71.0
# 937           NaN         65.0
# 938           NaN         82.0
# 939           NaN         65.0
# 940           NaN         73.0
#
#                                         Role/Affiliate
# 0                                                  NaN
# 1                                              No Data
# 2                                                  NaN
# 3     Originator Geneva Convention (Convention de G...
# 4                                                  NaN
# ..                                                 ...
# 936                                                NaN
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940                                                NaN
#
# [941 rows x 18 columns]

# %%
df['Organization Name'] = df['Organization Name'].fillna(df['Role/Affiliate'])
df
# Out:
#      Year    Category                                         Motivation  \
# 0    1901   Chemistry  in recognition of the extraordinary services h...
# 1    1901  Literature  in special recognition of his poetic compositi...
# 2    1901    Medicine  for his work on serum therapy, especially its ...
# 3    1901       Peace  The Nobel Peace Prize 1901 was awarded jointly...
# 4    1901       Peace                                      Not Specified
# ..    ...         ...                                                ...
# 936  2016    Medicine    for his discoveries of mechanisms for autophagy
# 937  2016       Peace  for his resolute efforts to bring the country'...
# 938  2016     Physics  for theoretical discoveries of topological pha...
# 939  2016     Physics  for theoretical discoveries of topological pha...
# 940  2016     Physics  for theoretical discoveries of topological pha...
#
#     Prize Share  Laureate ID                    Full Name  Birth Date  \
# 0           1/1          160  Jacobus Henricus van t Hoff  1852-08-30
# 1           1/1          569              Sully Prudhomme  1839-03-16
# 2           1/1          293       Emil Adolf von Behring  1854-03-15
# 3           1/2          462            Jean Henry Dunant  1828-05-08
# 4           1/2          463               Frederic Passy  1822-05-20
# ..          ...          ...                          ...         ...
# 936         1/1          927             Yoshinori Ohsumi  1945-02-09
# 937         1/1          934           Juan Manuel Santos  1951-08-10
# 938         1/2          928             David J Thouless  1934-09-21
# 939         1/4          929           F Duncan M Haldane  1951-09-14
# 940         1/4          930         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex  \
# 0            Rotterdam       Netherlands  Male
# 1                Paris            France  Male
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male
# 3               Geneva       Switzerland  Male
# 4                Paris            France  Male
# ..                 ...               ...   ...
# 936            Fukuoka             Japan  Male
# 937             Bogotá          Colombia  Male
# 938           Bearsden    United Kingdom  Male
# 939             London    United Kingdom  Male
# 940           Aberdeen    United Kingdom  Male
#
#                                      Organization Name Organization City  \
# 0                                    Berlin University            Berlin
# 1                                              No Data               NaN
# 2                                   Marburg University           Marburg
# 3     Originator Geneva Convention (Convention de G...               NaN
# 4                                                  NaN               NaN
# ..                                                 ...               ...
# 936                      Tokyo Institute of Technology             Tokyo
# 937                                                NaN               NaN
# 938                           University of Washington       Seattle, WA
# 939                               Princeton University     Princeton, NJ
# 940                                   Brown University    Providence, RI
#
#          Organization Country  Death Date Death City Death Country  \
# 0                     Germany  1911-03-01     Berlin       Germany
# 1                         NaN  1907-09-07   Ch tenay        France
# 2                     Germany  1917-03-31    Marburg       Germany
# 3                         NaN  1910-10-30     Heiden   Switzerland
# 4                         NaN  1912-06-12      Paris        France
# ..                        ...         ...        ...           ...
# 936                     Japan         NaN        NaN           NaN
# 937                       NaN         NaN        NaN           NaN
# 938  United States of America         NaN        NaN           NaN
# 939  United States of America         NaN        NaN           NaN
# 940  United States of America         NaN        NaN           NaN
#
#      Winning_age                                     Role/Affiliate
# 0           49.0                                                NaN
# 1           62.0                                            No Data
# 2           47.0                                                NaN
# 3           73.0   Originator Geneva Convention (Convention de G...
# 4           79.0                                                NaN
# ..           ...                                                ...
# 936         71.0                                                NaN
# 937         65.0                                                NaN
# 938         82.0                                                NaN
# 939         65.0                                                NaN
# 940         73.0                                                NaN
#
# [941 rows x 18 columns]

# %%
# Dropping the Role/Affiliate column as it is no longer needed
df = df.drop(['Role/Affiliate'], axis=1)
df
# Out:
#      Year    Category                                         Motivation  \
# 0    1901   Chemistry  in recognition of the extraordinary services h...
# 1    1901  Literature  in special recognition of his poetic compositi...
# 2    1901    Medicine  for his work on serum therapy, especially its ...
# 3    1901       Peace  The Nobel Peace Prize 1901 was awarded jointly...
# 4    1901       Peace                                      Not Specified
# ..    ...         ...                                                ...
# 936  2016    Medicine    for his discoveries of mechanisms for autophagy
# 937  2016       Peace  for his resolute efforts to bring the country'...
# 938  2016     Physics  for theoretical discoveries of topological pha...
# 939  2016     Physics  for theoretical discoveries of topological pha...
# 940  2016     Physics  for theoretical discoveries of topological pha...
#
#     Prize Share  Laureate ID                    Full Name  Birth Date  \
# 0           1/1          160  Jacobus Henricus van t Hoff  1852-08-30
# 1           1/1          569              Sully Prudhomme  1839-03-16
# 2           1/1          293       Emil Adolf von Behring  1854-03-15
# 3           1/2          462            Jean Henry Dunant  1828-05-08
# 4           1/2          463               Frederic Passy  1822-05-20
# ..          ...          ...                          ...         ...
# 936         1/1          927             Yoshinori Ohsumi  1945-02-09
# 937         1/1          934           Juan Manuel Santos  1951-08-10
# 938         1/2          928             David J Thouless  1934-09-21
# 939         1/4          929           F Duncan M Haldane  1951-09-14
# 940         1/4          930         J Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex  \
# 0            Rotterdam       Netherlands  Male
# 1                Paris            France  Male
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male
# 3               Geneva       Switzerland  Male
# 4                Paris            France  Male
# ..                 ...               ...   ...
# 936            Fukuoka             Japan  Male
# 937             Bogotá          Colombia  Male
# 938           Bearsden    United Kingdom  Male
# 939             London    United Kingdom  Male
# 940           Aberdeen    United Kingdom  Male
#
#                                      Organization Name Organization City  \
# 0                                    Berlin University            Berlin
# 1                                              No Data               NaN
# 2                                   Marburg University           Marburg
# 3     Originator Geneva Convention (Convention de G...               NaN
# 4                                                  NaN               NaN
# ..                                                 ...               ...
# 936                      Tokyo Institute of Technology             Tokyo
# 937                                                NaN               NaN
# 938                           University of Washington       Seattle, WA
# 939                               Princeton University     Princeton, NJ
# 940                                   Brown University    Providence, RI
#
#          Organization Country  Death Date Death City Death Country  \
# 0                     Germany  1911-03-01     Berlin       Germany
# 1                         NaN  1907-09-07   Ch tenay        France
# 2                     Germany  1917-03-31    Marburg       Germany
# 3                         NaN  1910-10-30     Heiden   Switzerland
# 4                         NaN  1912-06-12      Paris        France
# ..                        ...         ...        ...           ...
# 936                     Japan         NaN        NaN           NaN
# 937                       NaN         NaN        NaN           NaN
# 938  United States of America         NaN        NaN           NaN
# 939  United States of America         NaN        NaN           NaN
# 940  United States of America         NaN        NaN           NaN
#
#      Winning_age
# 0           49.0
# 1           62.0
# 2           47.0
# 3           73.0
# 4           79.0
# ..           ...
# 936         71.0
# 937         65.0
# 938         82.0
# 939         65.0
# 940         73.0
#
# [941 rows x 17 columns]

# %%
# Checking for missing values after performing the merge
df_orgName_nulls = df[df['Organization Name'].isnull()].shape[0]
print(df_orgName_nulls)
# Out:
# 73

# %% [markdown]
# It was also noticed that for some records, after merging, the <i>Organization Name</i> is not null yet contains the value <i>'No Data'</i>, which still needs to be replaced.

# %%
df_noData = df[df['Organization Name'] == 'No Data'].shape[0]
print(df_noData)
# Out:
# 89

# %% [markdown]
# So, there are now a total of 162 missing values in <i>Organization Name</i> after we performed the merge (73 are null ( meaning they were not found in <i>nobel_dataset</i>), and 89 are stored in the <i>nobel_dataset</i> as <i>'No Data'</i>).<br><br>
#
# We will therefore fill these remaining missing values with the value <i>'Self'</i>, which will be used to denote that this winner does not belong to an organization, since no value for the <i>Organization Name</i> for that winner was found.

# %%
# Filling the null values first
df['Organization Name'] = df['Organization Name'].fillna('Self')

# There are no null values
df_orgName_nulls = df[df['Organization Name'].isnull()].shape[0]
print(df_orgName_nulls)
# Out:
# 0

# %%
# Replacing the 'No Data' values with 'Self'
df.loc[df['Organization Name'] == 'No Data', ['Organization Name']] = 'Self'

# There are no 'No Data' values
df_noData = df[df['Organization Name'] == 'No Data'].shape[0]
print(df_noData)
# Out:
# 0

# %%
df[df["Motivation"]=="Not Specified"].count()
# Out:
# Year                    21
# Category                21
# Motivation              21
# Prize Share             21
# Laureate ID             21
# Full Name               21
# Birth Date              21
# Birth City              21
# Birth Country           21
# Sex                     21
# Organization Name       21
# Organization City        0
# Organization Country     0
# Death Date              19
# Death City              19
# Death Country           19
# Winning_age             21
# dtype: int64

# %% [markdown]
# <h1>Handling Duplicates</h1>
# We can now check for duplicate rows and drop them.

# %%
# duplicateRowsDF1 = df[df.duplicated(['Laureate ID','Motivation'])]
# duplicateRowsDF1

# %%
# Check the  duplicate rows based on the laureate id:
#duplicateRowsDF = df[df.duplicated(['Laureate ID','Organization Name'])] 
duplicateRowsDF = df[df.duplicated()] 
duplicateRowsDF 
print("The duplicated rows are of the following :", duplicateRowsDF['Full Name'], sep='\n')
df =df.drop_duplicates( subset=None, keep='first', inplace=False)
# Out:
# The duplicated rows are of the following :
# 283    Linus Carl Pauling
# Name: Full Name, dtype: object

# %%
duplicateRowsDF = df[df.duplicated()] 
print("The duplicated rows are of the following :", duplicateRowsDF['Full Name'], sep='\n')
duplicateRowsDF
# Out:
# The duplicated rows are of the following :
# Series([], Name: Full Name, dtype: object)
# Empty DataFrame
# Columns: [Year, Category, Motivation, Prize Share, Laureate ID, Full Name, Birth Date, Birth City, Birth Country, Sex, Organization Name, Organization City, Organization Country, Death Date, Death City, Death Country, Winning_age]
# Index: []

# %% [markdown]
# <h1>Count most frequent words </h1>
# <body>The next goal is to find the most repeated word in the <i>Motivation</i>, to find out the most topic female winners were involved in the category they win in the most. (Waiting for Basma)</body>

# %%
#create a dataset where the category is chemistry
cdf2= df[df["Category"]=="Chemistry"]
#find the most common 50 word
Counter(" ".join(cdf2["Motivation"]).split()).most_common(50)
# Out:
# [('of', 277),
#  ('the', 217),
#  ('for', 203),
#  ('his', 94),
#  ('and', 93),
#  ('in', 78),
#  ('their', 63),
#  ('development', 47),
#  ('on', 38),
#  ('chemical', 34),
#  ('discovery', 32),
#  ('to', 27),
#  ('work', 26),
#  ('studies', 25),
#  ('chemistry', 24),
#  ('synthesis', 23),
#  ('contributions', 23),
#  ('structure', 19),
#  ('recognition', 18),
#  ('organic', 18),
#  ('by', 17),
#  ('concerning', 17),
#  ('investigations', 13),
#  ('methods', 13),
#  ('into', 11),
#  ('high', 11),
#  ('discoveries', 11),
#  ('reactions', 11),
#  ('determination', 10),
#  ('especially', 10),
#  ('a', 10),
#  ('services', 9),
#  ('method', 9),
#  ('elements', 8),
#  ('invention', 8),
#  ('use', 8),
#  ('theory', 7),
#  ('fundamental', 7),
#  ('molecules', 7),
#  ('research', 7),
#  ('molecular', 7),
#  ('particularly', 7),
#  ('structures', 7),
#  ('mechanistic', 7),
#  ('has', 6),
#  ('compounds', 6),
#  ('substances', 6),
#  ('reaction', 6),
#  ('field', 6),
#  ('systems', 6)]

# %% [markdown]
# However, there are still some stop words that we would like to elimnate. Therefore, NLTK will be used along with regex expressions to remove stop words.

# %%
#Create a dataframe for chemistry category (Basma)
cdf2= df[df["Category"]=="Chemistry"]
#using NLTK to remove English stop words
stopwords = nltk.corpus.stopwords.words('english')
# RegEx for stopwords
REGEX_stopwords = r'\b(?:{})\b'.format('|'.join(stopwords))
# replace '|'-->' ' and drop all stopwords
words = (cdf2.Motivation
           .str.lower()
           .replace([r'\|', REGEX_stopwords], [' ', ''], regex=True)
           .str.cat(sep=' ')
           .split()
)

# generate a DF to hold the count for each word
rslt = pd.DataFrame(Counter(words).most_common(20),
                    columns=['Word', 'Count']).set_index('Word')
rslt.plot.bar(rot=0, figsize=(30,5), width=0.8) #create a bar chart with the most repeated words

# %% [markdown]
# WE CAN CHECK THE MOST REPEATED WORD FOR THE MOST INTERESTING CATEGORY IN FEMALES (MARWA)

# %% [markdown]
# Motivation missing 21 values (MARWA)

# %% [markdown]
# <h1> Observing coorelation between <i>Sex</i> and <i>Organization Country</i> </h1>
#     <body>A check, below, is made to observe the coorelation between the organization country and the sex. </body>

# %%
contengency_table = pd.crosstab(df["Organization Country"],df["Sex"], margins= True)
contengency_table
# Out:
# Sex                                  Female  Male  All
# Organization Country
# Alsace (then Germany, now France)         0     1    1
# Argentina                                 0     2    2
# Australia                                 0     6    6
# Austria                                   0     6    6
# Belgium                                   0     6    6
# Canada                                    0     7    7
# China                                     1     1    2
# Czechoslovakia                            0     1    1
# Denmark                                   0     9    9
# Federal Republic of Germany               1    25   26
# Finland                                   0     1    1
# France                                    3    37   40
# Germany                                   0    51   51
# Hungary                                   0     1    1
# India                                     0     1    1
# Ireland                                   0     1    1
# Israel                                    1     4    5
# Italy                                     1     5    6
# Japan                                     0    18   18
# Netherlands                               0    11   11
# Norway                                    1     4    5
# Portugal                                  0     2    2
# Russia                                    0     3    3
# Spain                                     0     1    1
# Sweden                                    0    17   17
# Switzerland                               0    22   22
# Union of Soviet Socialist Republics       0    11   11
# United Kingdom                            1    90   91
# United States of America                 10   354  364
# All                                      19   698  717

# %%
st.chi2_contingency(contengency_table)
# Out:
# (43.11942770884672,
#  0.9275813364191259,
#  58,
#  array([[2.64993026e-02, 9.73500697e-01, 1.00000000e+00],
#         [5.29986053e-02, 1.94700139e+00, 2.00000000e+00],
#         [1.58995816e-01, 5.84100418e+00, 6.00000000e+00],
#         [1.58995816e-01, 5.84100418e+00, 6.00000000e+00],
#         [1.58995816e-01, 5.84100418e+00, 6.00000000e+00],
#         [1.85495119e-01, 6.81450488e+00, 7.00000000e+00],
#         [5.29986053e-02, 1.94700139e+00, 2.00000000e+00],
#         [2.64993026e-02, 9.73500697e-01, 1.00000000e+00],
#         [2.38493724e-01, 8.76150628e+00, 9.00000000e+00],
#         [6.88981869e-01, 2.53110181e+01, 2.60000000e+01],
#         [2.64993026e-02, 9.73500697e-01, 1.00000000e+00],
#         [1.05997211e+00, 3.89400279e+01, 4.00000000e+01],
#         [1.35146444e+00, 4.96485356e+01, 5.10000000e+01],
#         [2.64993026e-02, 9.73500697e-01, 1.00000000e+00],
#         [2.64993026e-02, 9.73500697e-01, 1.00000000e+00],
#         [2.64993026e-02, 9.73500697e-01, 1.00000000e+00],
#         [1.32496513e-01, 4.86750349e+00, 5.00000000e+00],
#         [1.58995816e-01, 5.84100418e+00, 6.00000000e+00],
#         [4.76987448e-01, 1.75230126e+01, 1.80000000e+01],
#         [2.91492329e-01, 1.07085077e+01, 1.10000000e+01],
#         [1.32496513e-01, 4.86750349e+00, 5.00000000e+00],
#         [5.29986053e-02, 1.94700139e+00, 2.00000000e+00],
#         [7.94979079e-02, 2.92050209e+00, 3.00000000e+00],
#         [2.64993026e-02, 9.73500697e-01, 1.00000000e+00],
#         [4.50488145e-01, 1.65495119e+01, 1.70000000e+01],
#         [5.82984658e-01, 2.14170153e+01, 2.20000000e+01],
#         [2.91492329e-01, 1.07085077e+01, 1.10000000e+01],
#         [2.41143654e+00, 8.85885635e+01, 9.10000000e+01],
#         [9.64574616e+00, 3.54354254e+02, 3.64000000e+02],
#         [1.90000000e+01, 6.98000000e+02, 7.17000000e+02]]))

# %% [markdown]
# Since the <i>p</i> value is much greater than 0.05, then no coorelation is observed. Therefore, we will try to observe the country which has the most female Nobel Prize winners

# %%
df_female_institutes = df [df["Sex"]=="Female"]

# %%
female_country = df_female_institutes["Organization Country"].mode()
print(female_country)
# Out:
# 0    United States of America
# dtype: object

# %% [markdown]
# Seems like the USA has the most female Nobel prize winners. Let's see how did that change over the years.

# %%
df_female_institutes_USA = df_female_institutes[df_female_institutes["Organization Country"] == "United States of America"]

# %%
df_female_institutes_USA
CountStatus= df_female_institutes_USA["Year"].value_counts()
CountStatus
# Out:
# 2009    4
# 1983    1
# 1947    1
# 2004    1
# 1977    1
# 1963    1
# 1988    1
# Name: Year, dtype: int64

# %%
df_female_institutes_USA_copy = df_female_institutes_USA.copy() #copy the dataframe which contains the female winners from the USA
col1 = df_female_institutes_USA_copy['Year'] #NAME THE FIRST COLUMN YEAR
df_female_institutes_USA_copy = df_female_institutes_USA_copy.groupby('Year').size() #get the count of females per year in the USA
df_female_institutes_USA_copy = pd.DataFrame(df_female_institutes_USA_copy)
newcolname2 = {'Count'} #name the second column count
df_female_institutes_USA_copy.columns = newcolname2 #add the second column to the dataframe
df_female_institutes_USA_copy.plot(linestyle='-',figsize=(5,2)) #plot the data frame using a line graph

# %% [markdown]
# The graph demonstrates that there is a sharp increase in the count of female winners at around 2004 inside the United States of America.

# %% [markdown]
# <h1>What are the chances of you winning a Nobel prize</h1>
# <span> We first observe the unique values of <i> Birth Country</i>, then we see how many times each country had someone winning a nobel prize.  Finally, we calculate the percentage of every existing country winning a nobel prize. To elboarte, it is the percentage of the winners of a certain country with respect to the total number of winners. Accordingly, your chance to win a nobel prize will based on the winning percentage of that country.</span>

# %%
#get unique values and name their column as Birth Country
threecopy = df.copy()
threecopy = threecopy['Birth Country'].unique() # getting unique values of Birth Country
threecopy = pd.DataFrame(threecopy)
newcolname = {'Birth Country'} #The name of the new column in the dataset threecopy
threecopy.columns = newcolname

#get the count of each of the Birth Country and name their column as count
fourcopy = df.copy()
col1 = fourcopy['Birth Country'].unique()
fourcopy = fourcopy.groupby('Birth Country').size() # their count for each 
fourcopy = pd.DataFrame(fourcopy)
newcolname2 = {'count'}
fourcopy.columns = newcolname2


#merging unique birth country with their count:

onemerge = pd.merge(threecopy, fourcopy, on='Birth Country', how='outer')
onemerge.head(3)

#get percent of each country to see the chances of winning a nobel prize according to the country
col3 = onemerge['count']
numberoftotal = col3.sum()
fivecopy = onemerge.copy()
fivecopy = fivecopy.assign(chancesTowin = (col3 / numberoftotal) * 100)
fivecopy.head(3)
# see if the sum of values in percent chancesTowin equals to 100%
fivecopy['chancesTowin'].sum()
fivecopy.head(10)


#Check the percentage for a certain country winning the nobel prize
Questionnine = fivecopy[(fivecopy['Birth Country'] == "Netherlands")]
Questionnine
print(Questionnine['chancesTowin'])
# Out:
# 0    2.021277
# Name: chancesTowin, dtype: float64
