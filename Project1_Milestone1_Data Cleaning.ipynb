# %%
import pandas as pd
import datetime ## How many total missing values do we have?
from os import listdir # os is a module for interacting with the OS
from os.path import isfile, join # to verify file object, and concatenate paths
import glob # to find pathnames matching a specific pattern
import re # regular expressions :)

# %%
#import data set
df = pd.read_csv("./archive.csv")

# %%
#display sum of missing values
df_nulls = df.isnull().sum()
df_nulls
# Out:
# Year                      0
# Category                  0
# Prize                     0
# Motivation               88
# Prize Share               0
# Laureate ID               0
# Laureate Type             0
# Full Name                 0
# Birth Date               29
# Birth City               28
# Birth Country            26
# Sex                      26
# Organization Name       247
# Organization City       253
# Organization Country    253
# Death Date              352
# Death City              370
# Death Country           364
# dtype: int64

# %% [markdown]
# It seems like the Birth City is missing 28 values. Let's see which of the winners have those missing birth city values

# %%
#copy the full name, birth city, birth date, laureate type, organization city, organization name, and sex
newdf = df[['Full Name','Birth City','Birth Date', 'Laureate Type','Organization Country','Organization City','Organization Name','Sex']].copy()
newdf
#display the rows in which the Birth City is null
d1 = newdf[(newdf['Birth City'].isnull())]
d1
# Out:
#                                              Full Name Birth City  Birth Date  \
# 24   Institut de droit international (Institute of ...        NaN         NaN
# 61   Bureau international permanent de la Paix (Per...        NaN         NaN
# 90   Comité international de la Croix Rouge (Intern...        NaN         NaN
# 206  Office international Nansen pour les Réfugiés ...        NaN         NaN
# 222  Comité international de la Croix Rouge (Intern...        NaN         NaN
# 244              Friends Service Council (The Quakers)        NaN         NaN
# 245   American Friends Service Committee (The Quakers)        NaN         NaN
# 295  Office of the United Nations High Commissioner...        NaN         NaN
# 365  Comité international de la Croix Rouge (Intern...        NaN         NaN
# 366  Ligue des Sociétés de la Croix-Rouge (League o...        NaN         NaN
# 383            United Nations Children's Fund (UNICEF)        NaN         NaN
# 416         International Labour Organization (I.L.O.)        NaN         NaN
# 498                              Amnesty International        NaN         NaN
# 543  Office of the United Nations High Commissioner...        NaN         NaN
# 578  International Physicians for the Prevention of...        NaN         NaN
# 610                 United Nations Peacekeeping Forces        NaN         NaN
# 682   Pugwash Conferences on Science and World Affairs        NaN         NaN
# 705     International Campaign to Ban Landmines (ICBL)        NaN         NaN
# 728                           Médecins Sans Frontières        NaN         NaN
# 750                  Sir Vidiadhar Surajprasad Naipaul        NaN  1932-08-17
# 754                              United Nations (U.N.)        NaN         NaN
# 808          International Atomic Energy Agency (IAEA)        NaN         NaN
# 821                                       Grameen Bank        NaN         NaN
# 833   Intergovernmental Panel on Climate Change (IPCC)        NaN         NaN
# 880                                         Liu Xiaobo        NaN  1955-12-28
# 909                                European Union (EU)        NaN         NaN
# 927  Organisation for the Prohibition of Chemical W...        NaN         NaN
# 955                          National Dialogue Quartet        NaN         NaN
#
#     Laureate Type Organization Country Organization City Organization Name  \
# 24   Organization                  NaN               NaN               NaN
# 61   Organization                  NaN               NaN               NaN
# 90   Organization                  NaN               NaN               NaN
# 206  Organization                  NaN               NaN               NaN
# 222  Organization                  NaN               NaN               NaN
# 244  Organization                  NaN               NaN               NaN
# 245  Organization                  NaN               NaN               NaN
# 295  Organization                  NaN               NaN               NaN
# 365  Organization                  NaN               NaN               NaN
# 366  Organization                  NaN               NaN               NaN
# 383  Organization                  NaN               NaN               NaN
# 416  Organization                  NaN               NaN               NaN
# 498  Organization                  NaN               NaN               NaN
# 543  Organization                  NaN               NaN               NaN
# 578  Organization                  NaN               NaN               NaN
# 610  Organization                  NaN               NaN               NaN
# 682  Organization                  NaN               NaN               NaN
# 705  Organization                  NaN               NaN               NaN
# 728  Organization                  NaN               NaN               NaN
# 750    Individual                  NaN               NaN               NaN
# 754  Organization                  NaN               NaN               NaN
# 808  Organization                  NaN               NaN               NaN
# 821  Organization                  NaN               NaN               NaN
# 833  Organization                  NaN               NaN               NaN
# 880    Individual                  NaN               NaN               NaN
# 909  Organization                  NaN               NaN               NaN
# 927  Organization                  NaN               NaN               NaN
# 955  Organization                  NaN               NaN               NaN
#
#       Sex
# 24    NaN
# 61    NaN
# 90    NaN
# 206   NaN
# 222   NaN
# 244   NaN
# 245   NaN
# 295   NaN
# 365   NaN
# 366   NaN
# 383   NaN
# 416   NaN
# 498   NaN
# 543   NaN
# 578   NaN
# 610   NaN
# 682   NaN
# 705   NaN
# 728   NaN
# 750  Male
# 754   NaN
# 808   NaN
# 821   NaN
# 833   NaN
# 880  Male
# 909   NaN
# 927   NaN
# 955   NaN

# %% [markdown]
# <h1>Observation</h1>
# <span>As you might have noticed most of the Birth City missing values are coming from Laureate Type organization. Not only is the Birth City missing, but also the birth date, sex, organization name, country, and city. This makes sense, as winning as an organization means that you are a group of people which might come from different univeristies (organization), birth cities, organization countries, cities, and are of differenet sexes. Besides, each of them might have a different birth date</span>
#
# <span>Moreover, for the laureate type organization, the full name contains the name of the organization, not the name of the person. This is an indication that they are a group not an individual person who won the Nobel prize</span>

# %%
organizationCount = newdf[(newdf['Laureate Type']=="Organization")].count() 
# from the above line we can observe the number of existing birth city when the laureate type is organization

#check the number of rows with missing Birth City and laureate type of individual
countBirthIndividual = newdf[(newdf['Birth City'].isnull()) &(newdf['Laureate Type']=="Individual")].count()
display(organizationCount,countBirthIndividual)
# Out:
# Full Name               30
# Birth City               4
# Birth Date               4
# Laureate Type           30
# Organization Country     0
# Organization City        0
# Organization Name        0
# Sex                      4
# dtype: int64
# Full Name               2
# Birth City              0
# Birth Date              2
# Laureate Type           2
# Organization Country    0
# Organization City       0
# Organization Name       0
# Sex                     2
# dtype: int64

# %% [markdown]
# <h1>Checking number of organization laureate type</h1>
# <span>What we want to observe is the number of organization laureate type, and those with missing birth city, organization name, organization country, organization city, birth date, and sex</span>

# %%
missingOrganization = newdf[(newdf['Laureate Type']=="Organization")&(newdf['Organization Name'].isnull())&(newdf['Organization City'].isnull())&(newdf['Organization Country'].isnull())&(newdf['Birth City'].isnull())&(newdf['Sex'].isnull())&(newdf['Birth Date'].isnull())].count()
missingOrganization
# Out:
# Full Name               26
# Birth City               0
# Birth Date               0
# Laureate Type           26
# Organization Country     0
# Organization City        0
# Organization Name        0
# Sex                      0
# dtype: int64

# %% [markdown]
# <h1> Analyzing the above result </h1>
# The number of rows of laureate type organization which contain missing organization info, sex, birth date, and birth city are 26/30 rows. Likewise, only 4 rows contained birth city even without checking on the organization info (Organization name, city, and country). Now let's check the rows which contain the birth city and are of laurete type orgainzation.

# %%
#checking the 4 rows which contain birth date, birth city, sex, and are of type organization
laureate_org_expection = newdf[(newdf['Laureate Type'] == 'Organization') & (newdf['Sex'].notnull()) & (newdf['Birth Date'].notnull())& (newdf['Birth City'].notnull())]
laureate_org_expection
# Out:
#                                Full Name        Birth City  Birth Date  \
# 452                           Le Duc Tho   Nam Ha province  1911-10-14
# 520                        Mother Teresa    Uskup (Skopje)  1910-08-26
# 620  The 14th Dalai Lama (Tenzin Gyatso)           Taktser  1935-07-06
# 640                     Aung San Suu Kyi  Rangoon (Yangon)  1945-06-19
#
#     Laureate Type Organization Country Organization City Organization Name  \
# 452  Organization                  NaN               NaN               NaN
# 520  Organization                  NaN               NaN               NaN
# 620  Organization                  NaN               NaN               NaN
# 640  Organization                  NaN               NaN               NaN
#
#         Sex
# 452    Male
# 520  Female
# 620    Male
# 640  Female

# %% [markdown]
# <h1> Why do sexes, birth dates, and borth cities exist above? </h1>
# <span>It seems like not only the birth city, birth date, and sex exist, but also, the full names are names of actual people and not a group. This might indicate that those people were part of an organization, or this data is mistakenly categorized as of laureate type <span style ="font-style:italic">Organization<span> </span>

# %% [markdown]
# <h1>Checking if we can drop rows of <span style ="font-style:italic">Laureate Type:</span> <span style ="font-style:italic">Organization<span> </h1>
# <span>Let's check how many rows of type organization exist. If they are less or equal to 3% perecent of the data, we will choose to drop any column of type organization and focus our study on individuals</span>

# %%
# How many total missing values do we have?
# shape returns the dimentionality of a dataframe (rows and columns)
# how many rows exist in the data set
dfNumofRows = df.shape[0]
# how many rows exist with type organization
laureateOrganization_df = newdf[(newdf['Laureate Type']=="Organization")]
orgNumofRows= laureateOrganization_df.shape[0]
#calculate the perecentage of organization data with respect to the whole data set
perc_drop= (orgNumofRows/dfNumofRows)*100
perc_drop
# Out:
# 3.0959752321981426

# %% [markdown]
# Since the perecentage of the rows to be dropped, rows which carry laureate type <span style ="font-style:italic">Organization</span> is approximately 3, we will choose to drop those rows.

# %%
#drop the rows of type organization
df = df[df['Laureate Type'] != "Organization"]

# %%
df
# Out:
#      Year    Category                                           Prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 964  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965  2016       Peace                      The Nobel Peace Prize 2016
# 966  2016     Physics                 The Nobel Prize in Physics 2016
# 967  2016     Physics                 The Nobel Prize in Physics 2016
# 968  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             Motivation Prize Share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 964  "for his discoveries of mechanisms for autophagy"         1/1
# 965  "for his resolute efforts to bring the country...         1/1
# 966  "for theoretical discoveries of topological ph...         1/2
# 967  "for theoretical discoveries of topological ph...         1/4
# 968  "for theoretical discoveries of topological ph...         1/4
#
#      Laureate ID Laureate Type                     Full Name  Birth Date  \
# 0            160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1            569    Individual               Sully Prudhomme  1839-03-16
# 2            293    Individual        Emil Adolf von Behring  1854-03-15
# 3            462    Individual             Jean Henry Dunant  1828-05-08
# 4            463    Individual                Frédéric Passy  1822-05-20
# ..           ...           ...                           ...         ...
# 964          927    Individual              Yoshinori Ohsumi  1945-02-09
# 965          934    Individual            Juan Manuel Santos  1951-08-10
# 966          928    Individual             David J. Thouless  1934-09-21
# 967          929    Individual          F. Duncan M. Haldane  1951-09-14
# 968          930    Individual         J. Michael Kosterlitz  1943-06-22
#
#             Birth City     Birth Country   Sex              Organization Name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 964            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 965             Bogotá          Colombia  Male                            NaN
# 966           Bearsden    United Kingdom  Male       University of Washington
# 967             London    United Kingdom  Male           Princeton University
# 968           Aberdeen    United Kingdom  Male               Brown University
#
#     Organization City      Organization Country  Death Date Death City  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 964             Tokyo                     Japan         NaN        NaN
# 965               NaN                       NaN         NaN        NaN
# 966       Seattle, WA  United States of America         NaN        NaN
# 967     Princeton, NJ  United States of America         NaN        NaN
# 968    Providence, RI  United States of America         NaN        NaN
#
#     Death Country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 964           NaN
# 965           NaN
# 966           NaN
# 967           NaN
# 968           NaN
#
# [939 rows x 18 columns]

# %%
# we can drop the Laureate Type column since it is the same for all rows (records).
df['Laureate Type'].nunique()
# Out:
# 1

# %% [markdown]
# <h1>Handling Duplicates</h1>
# We can now check for duplicate rows (rows with the same <span style="font-style:italic">Laureate ID</span>), and drop them.

# %%
# # Check the  duplicate rows based on the laureate id:
# duplicateRowsDF = df[df.duplicated(['Laureate ID'])] 
# print("The rows with the same laureate ID are:", duplicateRowsDF['Full Name'], sep='\n')

# #drop those cols which are repeated
# #df.drop_duplicates('Laureate ID')

# %% [markdown]
# <h1>Check missing <span style="font-style:italic">Birth Dates</h1>
# <body>Now that the data contains indivdual laureates only, let's check how many of them is missing the birth date, given that we have dropped the organization laureates which had missing birth dates as they were groups, and dropped duplicates.</body>

# %%
newdf = df[['Full Name','Birth City','Laureate ID']].copy()
newdf[newdf["Birth City"].isnull()]
# Out:
#                              Full Name Birth City  Laureate ID
# 750  Sir Vidiadhar Surajprasad Naipaul        NaN          747
# 880                         Liu Xiaobo        NaN          855

# %%
 # Select all duplicate rows based on one column
# duplicateRowsDF = df[df.duplicated(['Laureate ID'])]
#  df
# #print("Duplicate Rows based on a single column are:", duplicateRowsDF, sep='\n')
